# %%
import re
import pickle
import pandas as pd

def save_for_training(list_to_save, save_name):
    """
    __ Parameters __
    [1D] list_to_save:  to the pkl file
    [string] save_name: column under which to save

    __ Description __
    Append to the pkl file
    """
    temp = pd.read_pickle("adv02_training_dataset.pkl")
    
    temp[save_name] = list_to_save

    with open("adv02_training_dataset.pkl", 'wb') as fout:
        pickle.dump(temp, fout)

def read_pickle(file_name_to_read="adv02_training_dataset.pkl"):
    """
    __ Parameters __
    [str] file_name_to_read:    and load data from
    """

    return pd.read_pickle(file_name_to_read)

# %% [markdown]
# # Datacleaning and why even use them
# ***
# Every single neural network at <font color=purple>Dreams AI</font>, regardless of it's architecture (from the simple 2-layer with Relu Activation to a big-brained Bayesian Network) or the genius that stands behind it's creation, requires a good quality dataset to be trained on.
#
# Such a dataset would be a collection of **properties**, **labelled** into **fields**. In the ideal case scenario, data is **labelled** as it is acquired by either:
# - Chinese worker diligently copying and pasting information from emails into a spreadsheet;
# - `Selenium` or `cdp` web scraper that allocates properties depdning on their position on the webpage e.g. titles → Brand, Timestamp → Unique ID etc.
#
# <img src="images/clean_dataset.png" title="Clean dataset" />
#
# However such unregulated **Feature Extraction** can occassionally lead to errors in the form of:
# - Typograhpical errors;
# - Incorrect field classification (*below is an example of the `Brand` being cluttered with properties that should be in the `description`*).
#
# <img src="images/dirty_dataset.png" title="Dirty dataset" />
#
# ## The dataset used is the same as from the DataFrame tutorial, with fields
# <center><font color=red>Brand, Description, Part Number, Price, Qty</font>, Remark, GroupName, UniqueID</center>
#
# The highghted fields have numererous errors that need to be cleaned.

# %% [markdown]
# # Example use-case of regular experssions
# **Regular expressions** are used to catch word patterns to correct such errors. Consider regular experssion as a heavily-roided word search that, appart from simple words, can search for letter-number combinations, multiple words, words endings, etc.
#
# The regexp procedure in the code below eleminates errors from the brand column of the above set.
#
# *It will become clear what it all means by the end of the tutorial*
# ***
# 1. Build regular expression to catch "Orig" and "[stuff in square brackets]":
# ```python
# regexp = r"\b(Orig)|(\[.*?\])"
# ```
# <img src="images_inkscape/filtering_brand.png" title="Filtering out the brand"/>
# 2. <font color=red><b>Very important to have the leading `r` as it ensures that backslahes are passed on without modification</b></font>.
# 3. Call the regular experssion function (in this case `re.sub` replace the pattern that is found with an empty string):
# ```python
# mg = re.sub(regexp, "", i)
# ```
# 4. Ignore the case of what is being matched:
# ```python
# re.IGNORECASE
# ```
# 5. Search proceeds left to right, returning matched patterns or `None` if nothing was found.

# %%
########################################
# 🍏 Example showing a typical use case of regexp
########################################
# 1 - load data in
brand = read_pickle()['example-1']

# 2 - construct regexp
regexp = r"\b(Orig)|(\[.*?\])"

# 3 - run through the list and remove "orig" and "[1Gx8...]"
for i in brand:
    mg = re.sub(regexp, "", i, re.IGNORECASE)
    print(mg, "\t\t←\t\t", i)
# Out:
# Samsung  		←		 Samsung Orig
# Kingston   		←		 Kingston Orig [1Gx8 16C]
# Crucial  		←		 Crucial Orig
# Samsung   		←		 Samsung Orig [1Gx8 16C]
# MIcron   		←		 MIcron Orig [1Gx8 16C]
# Hynix   		←		 Hynix Orig [1Gx8 16C]
# Micron   		←		 Micron Orig [1Gx8 16C]
# Hynix   		←		 Hynix Orig [1Gx8 16C]
# OEM 		←		 OEM
# Micron   		←		 Micron Orig [1Gx8 8C]
# Samsung   		←		 Samsung Orig [1Gx8 8C]
# Samsung   		←		 Samsung Orig [1Gx8 8C]
# Micron   		←		 Micron Orig [1Gx8 8C]
# Crucial  		←		 Crucial Orig
# Hynix   		←		 Hynix Orig [1Gx8 8C]
# Hynix   		←		 Hynix Orig [1Gx8 8C]
# OEM 		←		 OEM
# Hynix   		←		 Hynix Orig [512Mx64 8C]
# Samsung   		←		 Samsung Orig [512Mx16 4C]
# Kingston retail  		←		 Kingston retail [512Mx8 8C]
# Samsung   		←		 Samsung Orig [512Mx16 4C]
# Samsung   		←		 Samsung Orig [512Mx8 8C]
# Micron 		←		 Micron
# Micron   		←		 Micron Orig [512Mx16 4C]
# Hynix   		←		 Hynix Orig [512Mx64 8C]
# Samsung 		←		 Samsung

# %% [markdown]
# # 1 - Basics of regular expressions
# Basic regular expression patterns match single characters:
#
# <table class="table table-striped table-bordered table-hover table-condensed">
# <colgroup>
# <col  class="left">
# <col  class="left">
# </colgroup>
# <thead>
# <tr>
# <th scope="col" class="text-left"><b>Characters</b></th>
# <th scope="col" class="text-left"><b>Description</b></th>
# </tr>
# </thead>
# <tbody>
#
# <tr>
# <td class="text-left"><code>"a", "X", "9", etc</code></td>
# <td class="text-left">Normal characters <font color=red>(Characters with special meaning need to be backslashed: "^" "$" "*" "+" "?" "{" "[" "]" "\" "|" "(" ")" </font></td>
# </tr>                                                                                                                                           <tr>                                                                                                                 <td class="text-left">"."</td>
# <td class="text-left">Matches any character except for newline</td>
# </tr>
#                                                                                                                      <tr>
# <td class="text-left"><code>"\d"</code> (<code>"\D"</code> complement set)</td>
# <td class="text-left">Decimal digits ↔ [0-9]</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"\s"<code> (<code>"\S"</code> complement set)</td>
# <td class="text-left">White-space character</td>
# </tr>
#                                                                                                                     <tr>
# <td class="text-left"><code>"\w"<code> (<code>"\W"</code> complement set)</td>
# <td class="text-left">Word characters ↔ [0-9a-zA-Z] - <font color=red>Though called word, this only watches a <b>single</b> word character not a full word</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"A|B"</code></td>
# <td class="text-left">Match either A or B</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"[✘✘✘✘]"</code></td>
# <td class="text-left">A set of characters, all of which will produce a match <font color=red>☩</font></td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"[^✘✘✘]"</code></td>
# <td class="text-left">Anything <font color=red><b>except</b></font> these characters will produce a match</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"^"</code></td>
# <td class="text-left">Matches begginning of line - rarely used</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"$"</code></td>
# <td class="text-left">Matches end of line - rarely used</td>
# </tr>
#
# </tbody>
# </table>
# <font color=red>☩ A range of characters can be specified e.g. `A-Z, a-z, 0-9`</font>

# %%
########################################
# 🍏 Basic examples
########################################
# 1 - load the data
brand = ["Intel", "intel", "Intel2010", "Intel2011", "Intel2012", "AMD Pro"]

# 2 - regular expression to catch all of above cases
regexp = "Intel\d\d\d\d|[iI]ntel|AMD\sPro"

for idx, i in enumerate(brand):

    # 3 - try to match one of the brands
    mg = re.search(regexp, i, re.IGNORECASE)
    
    if(mg is None):
        # 4 - print if brand did not exist
        print(i)print("✘ Error with\t", i)
    else:
        brand[idx] = mg.group()

print(brand)
# Out:
# ['Intel', 'intel', 'Intel2010', 'Intel2011', 'Intel2012', 'AMD Pro']

# %%
########################################
# 📓 Modify the regexp by manually adding the possible brands using the "|" separator
########################################
# 1 - load the data
brand = read_pickle("datasets/DRAM_OfferScraperOutput.pkl")['Brand']

# 2 - Use regular experssions to explicitly spell out brand that are accepted
regexp = "SK Hynix|Samsung|Hynix|Micron"

for idx, i in enumerate(brand):

    # 3 - try to match one of the brands
    mg = re.search(regexp, i, re.IGNORECASE)
    
    if(mg is None):
        # 4 - print if brand did not exist
        print("✘ Error with\t", i)
    else:
        brand[idx] = mg
# Out:
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda
# Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda / Infineon
# Qimonda / Infineon
# Qimonda / Infineon
# Elixir
# Elixir
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Nanya
# Nanya
# Nanya
# Nanya
# Winbond
# Elixir
# Elixir
# Elixir
# Elixir
# Winbond
# Winbond
# Elixir
# Elixir
# Nanya
# Elixir Orig
# Elixir Orig
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Spectek
# Spectek
# Nanya
# Nanya
# Nanya
# Nanya
# Spectek
# Nanya
# Spectek
# Spectek
# Nanya
# Spectek
# Nanya
# Sandisk
# Nanya
# Spectek
# Nanya
# Spectek
# Nanya
# Spectek
# Spectek
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Toshiba
# Elpida
# Nanya
# Spectek
# Elpida
# Elpida
# Nanya
# Elpida
# Elpida
# Elpida
# Elpida
# Kingston
# Kingston
# Kingston
# Spectek
# Spectek
# Spectek
# Nanya
# Spectek
# Nanya
# Nanya
# Nanya
# Nanya ETT
# Nanya
# Nanya
# Spectek
# Spectek
# Spectek
# Nanya
# Nanya
# Nanya
# Spectek
# Winbond
# Nanya
# Nanya
# ISSI
# Etron
# Winbond
# Winbond
# Etron
# ISSI
# Nanya
# Nanya
# Nanya
# Spectek
# Nanya
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Nanya
# Elpida
# Elpida
# Spectek
# Spectek
# Spectek
# Elixir
# Nanya
# Elpida
# Spectek
# Spectek
# Elpida
# Elpida
# Elpida
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# OEM Mira
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Nanya
# Nanya
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Nanya
# Elpida
# Elpida
# Elpida
# Spectek
# Elixir
# Spectek/Blank
# Spectek
# Spectek
# Elpida
# Mira
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# ELPIDA Salvage
# ELPIDA
# Nanya ETT
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Nanya
# Nanya
# Speteck
# Spectek
# Spectek
# Spectek
# Elpida FT
# OEM Spectek
# Nanya/Blank
# Elpida
# Elpida Salvage
# Spectek
# Spectek
# Spectek
# Spectek
# Elpida Salvage
# Elpida Salvage
# Elpida ETT
# Elpida
# Spectek
# Spectek
# Elpida
# Nanya
# Nanya
# Nanya
# Elpida
# Nanya
# Nanya
# Nanya
# Nanya
# ISSI
# ISSI
# ISSI
# ISSI
# Spectek
# Nanya
# Spectek
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Elpida
# Nanya
# Nanya
# Nanya
# Elpida
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Spectek
# Nanya
# Nanya
# Elpida Salvage
# Nanya
# Spectek
# Nanya
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Crucial
# Elpida
# Elpida
# Nanya
# Elpida
# Nanya
# Nanya
# Nanya
# Spectek
# Elpida
# Nanya
# Spectek
# Nanya
# Spectek
# Nanya
# Spectek
# Elpida
# Elpida
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Elixir
# Nanya
# Elixir
# Nanya ETT
# Promos
# Elpida
# Elpida
# Spectek
# Elpida
# Nanya
# Elixir
# Elixir
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Kingston
# Kingston
# Kingston
# ISDT
# Nanya
# Nanya
# Nanya
# Nanya
# Etron
# Elpida
# Elpida
# Elpida
# Elpida
# Nanya
# Spectek
# Etron
# Etron
# Nanya
# Nanya
# Nanya
# Nanya
# Winbond
# Nanya
# Nanya
# Nanya
# Alliance
# Nanya
# Nanya
# Elixir
# Elpida
# Elpida
# Qimonda ETT
# Nanya
# Elixir
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Winbond
# Winbond
# Elpida
# Winbond
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Etron
# Etron
# Nanya
# OEM Spectek
# Nanya
# Spectek
# Spectek
# Elpida
# Elpida
# Nanya
# Nanya
# Nanya
# Nanya
# OEM Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Elpida
# Elpida
# Spectek
# Elpida Salvage
# Nanya ETT
# OEM Spectek
# OEM NANYA
# Elpida
# Nanya/Blank
# Nanya
# Nanya
# Nanya eTT
# Nanya eTT
# Nanya eTT
# OEM Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Mira ETT
# Mira
# Mira ETT
# Nanya UTT
# Elpida
# Elpida ETT
# NANYA (U-BIN)
# NANYA (U-BIN)
# NANYA (U-BIN)
# NANYA (U-BIN)
# Spectek original
# Spectek original
# Spectek original
# Spectek SSSK
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek original
# Spectek
# Nanya
# Nanya
# Spectek original
# Speteck UTT
# Spectek
# Mira
# Nanya
# Nanya
# Elixir
# Elpida Original
# Elixir
# Elixir
# Elpida
# Elpida (Salvage)
# Spectek
# Spectek
# Spectek
# Nanya
# Elpida Original
# Elpida ETT
# Elpida ETT
# Elpida Salvage
# Elpida UTT
# Elpida ETT
# Elpida Original
# Elpida Salvage
# Elpida UTT
# Elpida FT
# Elpida Die
# SSWT
# Spectek
# Winbond
# Nanya
# Nanya
# Spectek
# Spectek
# Spectek
# Nanya
# Spectek
# Elpida ETT
# Elpida ETT
# Elpida
# Elpida
# Elpida
# Spectek
# Spectek
# Nanya
# Spectek
# Spectek
# Spectek
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Elixir
# OEM Spectek
# Winbond
# Nanya
# Nanya
# Spectek
# Spectek
# Spectek
# Elpida
# Elpida ETT
# Elpida ETT
# Elpida ETT
# Elpida ETT
# Elpida ETT
# Elpida ETT
# Elpida original
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Speteck
# Speteck
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Elpida
# Elixir
# mira
# Mira
# mira
# Mira
# Nanya
# mira
# Nanya
# Nanya/Blank
# Nanya ETT
# Elpida
# Elpida
# Nanya ETT
# Nanya
# Nanya
# Nanya/FT
# Qimonda UTT
# Promos/UTT
# OEM Promos ETT
# Qimonda UTT
# Qimonda
# Elpida
# Elpida
# Elpida ETT
# Spectek
# Spectek
# Nanya
# Elixir
# Nanya
# Nanya
# Nanya
# Elixir
# Nanya ETT
# Nanya
# Nanya
# OEM NANYA
# Nanya
# Elpida
# Nanya
# Nanya
# Nanya
# Elpida
# Mira ETT
# Nanya
# Nanya
# Elpida
# Elpida
# Elpida
# Elpida
# Nanya
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Spectek
# Elpida
# Elpida
# Elpida Salvage
# Elpida
# Elpida Original
# Elpida Original
# Nanya
# Nanya
# ISSI
# ISSI
# Nanya
# Nanya
# Nanya ETT
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Spectek
# Spectek
# Spectek
# Spectek
# Nanya
# Nanya
# Nanya
# ISSI
# ISSI
# Nanya
# Winbond
# Winbond
# Winbond
# Winbond
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida Salvage
# Qimonda
# Spectek
# Winbond
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Nanya
# Winbond
# Winbond
# Elpida
# Winbond
# Nanya
# Nanya
# Elpida
# Nanya
# Nanya
# Winbond
# Nanya
# Nanya
# Nanya
# Winbond
# Winbond
# Qimonda
# Elpida
# Elpida
# Elpida
# Elpida
# Spectek Die
# Elpida
# Elpida
# Elpida
# SCSemicon
# Winbond
# Winbond
# Winbond
# Promos
# Elpida UTT
# Elpida UTT
# Elpida UTT
# Elpida
# Elpida
# Winbond
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Qimonda
# Elpida
# ETT (Elpida)
# ETT (Elpida)
# ETT (Elpida)
# ETT (Elpida)
# ETT (Elpida)
# ETT (Mira)
# ETT (Mira)
# ETT (Mira)
# ETT (Mira)
# Nanya ETT
# Nanya ETT
# Nanya ETT
# Nanya ETT
# Nanya UTT
# Nanya UTT
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# OEM Promos ETT
# OEM Promos ETT
# OEM Promos ETT
# PIECEMAKERS
# PROMOS die
# PROMOS UTT
# Promos
# Promos
# Promos
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Rexchip( Elpida Die ) ETT
# Rexchip( Elpida Die ) ETT
# Rexchip( Elpida Die ) ETT
# Spectek Orig
# Spectek
# Spectek
# Winbond
# Winbond
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda
# Qimonda
# Winbond
# Winbond
# Winbond
# Winbond
# Elpida
# Elpida
# Elpida
# PIECEMAKERS
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# ETT (Spectek)
# Elixir
# ETT (Winbond)
# Elixir
# Etron
# Etron
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# OEM Spectek
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya ETT DIE
# Promse
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Promos
# Promos
# Promos
# Nanya
# Etron
# Etron
# Etron
# Etron
# Etron
# Nanya ETT
# Nanya Orig
# Mira
# Mira
# Mira
# Spectek
# Nanya ETT
# Nanya ETT
# Spectek
# Spectek
# Spectek
# Spectek
# Winbond
# Spectek
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Promos
# Nanya
# Promos
# Promos
# Promos
# Nanya
# Nanya
# Nanya
# Nanya
# Mira
# Mira
# Mira ETT
# Mira ETT
# Mira
# ETT
# Elpida
# Elpida
# Elpida
# Elpida
# Blank Promos
# Blank ETT
# Elixir
# Elixir
# Elixir
# Elpida
# Elpida
# Elpida
# PIECEMAKERS
# Elpida
# Elpida
# Promos
# Promos
# Promos
# OEM Spectek
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya ETT DIE
# Qimonda
# Qimonda
# Qimonda
# Zentel
# Qimonda
# Qimonda
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Etron
# OEM Promos ETT
# Etron
# Elixir
# Elixir
# OEM Promos ETT
# OEM Elpida
# Elpida
# Elixir
# Winbond
# Winbond
# Qimonda
# Elpida
# Elpida
# Nanya
# Elpida
# Elpida
# Elpida
# Elpida
# Qimonda
# Qimonda
# Elpida
# Winbond
# Qimonda/Infineon
# Qimonda/Infineon
# Spectek
# QIMONDA
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Nanya
# Nanya
# Nanya
# Mira ETT
# Nanya
# ETT (Elpida)
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Blank (Elpida die)
# A-data
# A-data
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# ETT (Qimonda Die)
# Infineon / Qimonda
# Nanya
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# QIMONDA
# UTT
# Winbond
# Elixir
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Qimonda
# Qimonda
# Nanya
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# QIMONDA
# Promos
# Spectek die
# Promos
# Promos
# Mira
# Promos
# Promos
# Spectek die
# Nanya
# Mira
# Elixir
# OEM Mira ETT
# Nanya
# UTT-Mira
# UTT
# Spectek
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Promos
# OEM ETT
# OEM ETT
# OEM BLANK
# Nanya
# Nanya
# Mira
# Mira UTT
# Mira UTT
# Mira Blank
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# ETT (Mira Die)
# ETT (Mira Die)
# ETT (Mira Die)
# ETT (Elpida Die)
# ETT (Elpida Die)
# ETT (Elpida Die)
# ETT (Elpida Die)
# ETT (Elpida Die)
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida ETT
# Blank ETT
# QIMONDA
# QIMONDA
# Qimonda
# Elixir
# Elixir
# Elixir
# Elixir
# Elpida ETT
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Winbond
# Infineon / Qimonda
# Infineon / Qimonda
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# ISSI
# Qimonda ETT
# Nanya
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Spectek
# UTT
# Winbond
# Promos
# Mira
# QIMONDA
# Qimonda
# OEM ETT
# Infineon / Qimonda
# Elpida
# Nanya
# Qimonda
# Qimonda
# QIMONDA
# QIMONDA
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# QIMONDA
# QIMONDA
# Qimonda
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda(Infineon)
# Infineon / Qimonda
# Infineon / Qimonda
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Qimonda
# Nanya
# Infineon / Qimonda
# Elpida
# Elpida
# Elpida
# Qimonda
# Qimonda / Infineon
# Nanya
# Nanya
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Nanya
# Nanya
# OEM Blank
# Qimonda
# Spectek
# UTT
# StarRam
# Qimonda
# Nanya
# Qimonda
# Qimonda
# Qimonda
# OEM Promos
# Nanya
# Nanya
# Nanya
# Infineon / Qimonda
# Infineon / Qimonda
# QIMONDA
# QIMONDA
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elixir
# Elixir
# Infineon / Qimonda
# Elixir
# Nanya
# StarRam
# Qimonda
# Qimonda
# Qimonda
# QIMONDA
# QIMONDA
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Nanya
# Qimonda / Infineon
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Nanya
# Nanya
# Qimonda / Infineon
# Qimonda
# Qimonda
# Qimonda
# Nanya
# Nanya
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda
# Qimonda
# Infineon / Qimonda
# Etron
# Qimonda
# Nanya
# Qimonda
# Qimonda
# Qimonda
# Infineon / Qimonda
# ---
# Qimonda
# Qimonda
# Promos
# Qimonda
# Qimonda
# Elixir
# Qimonda
# Nanya
# Elixir
# Elpida
# Winbond
# ISSI
# ISSI
# ISSI
# ISSI
# Zental
# Alliance Memory
# Etron
# Etron
# Etron
# PIECEMAKERS
# Winbond
# Nanya
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Majors
# Nanya
# Qimonda
# Zentel
# Blank / Elpida die
# Elpida ETT
# Elpida ETT
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# ETT (Promos)
# ETT (Promos)
# ETT
# ETT (Promos)
# ETT (Promos)
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Nanya
# Nanya
# Nanya
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Nanya
# Nanya
# Mira
# Mira
# Promos
# Promos
# Promos
# Promos
# Mira
# Mira
# Promos
# Promos
# Promos
# Mira
# Mira
# Nanya
# Nanya
# Nanya
# Nanya
# Promos
# OEM Promos ETT
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Nanya ETT
# Qimonda/ / Infineon
# Promos UTT
# Etron
# Spectek
# StoneTiger
# Nanya
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Elixir
# Elixir
# Elixir
# Elixir
# Elixir
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Zentel
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mira
# Etron
# Etron
# Etron
# Etron
# Mira
# Mira
# Mira
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Etron
# Etron
# Nanya
# Nanya
# Promos
# PSC
# Promos
# Promos
# Qimonda
# Promos
# PSC
# Qimonda
# Qimonda
# Elixir
# Spectek
# Spectek
# Elpida
# Elpida UTT
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# ETT ( Elpida ) blank
# ETT ( Elpida )
# ETT (Promos)
# MIRA ETT
# ---
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mira UTT
# Mosel Vitelic
# Mosel Vitelic
# Mosel Vitelic
# Mosel Vitelic
# Mosel Vitelic
# Mosel Vitelic
# Mosel Vitelic
# Nanya
# Nanya
# Nanya
# Nanya
# OEM
# Powerchip
# OEM
# Powerchip
# Promos
# Qimonda
# StoneTiger
# uTT ( Elpida )
# UTT ( Mosel )
# UTT - Mira
# UTT - Mira
# UTT Mira
# UTT
# UTT
# UTT
# UTT
# Winbond
# Winbond
# Blank
# Zentel
# Mira
# Elixir Orig
# Elixir Orig
# Elixir
# Elixir
# Elixir
# Elixir
# Elpida OEM mark
# Elixir
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# ISSI
# Infineon (Qimonda)
# Infineon (Qimonda)
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon/ Qimonda
# Mosel Vitelic / ProMos
# Mosel Vitelic
# ProMos
# Mosel Vitelic
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# OEM CEON
# ProMos
# PSC
# PSC
# Qimonda
# Qimonda
# Qimonda
# Zentel
# Qimonda
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Infineon / Qimonda
# Etron
# Elixir
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Etron
# Etron
# Infineon / Qimonda
# Infineon / Qimonda
# Nanya
# Nanya
# ProMOS
# Qimonda
# Winbond
# Elpida
# Etron
# Etron
# Elpida
# Nanya
# Elpida
# Qimonda
# ESMT
# ESMT
# ESMT
# ESMT
# QIMONDA
# QIMONDA
# QIMONDA
# QIMONDA
# QIMONDA
# QIMONDA
# QIMONDA
# Infineon / Qimonda
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Majors
# Qimonda
# Nanya
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# QIMONDA
# Nanya
# Nanya
# Qimonda
# Nanya
# Qimonda
# Qimonda/ / Infineon
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Elixir
# Elixir
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# QIMONDA
# Promos
# Elixir
# Elixir
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Nanya
# Nanya
# Nanya
# ProMOS
# ProMOS
# Qimonda
# Qimonda
# Qimonda
# QIMONDA
# QIMONDA
# QIMONDA
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mitsubishi
# Mosel Vitelic
# Nanya
# Nanya
# OEM PSC
# OEM
# Powerchip
# Spectek
# UTT - Mira
# UTT - Mira
# UTT - Mira
# UTT - Mosel
# UTT
# UTT
# Winbond
# Winbond
# Infineon / Qimonda
# Infineon / Qimonda
# Nanya
# Nanya
# Elixir
# Elixir Orig
# QIMONDA
# Elixir
# QIMONDA
# Elpida Die
# Elpida
# Elpida
# Elpida
# QIMONDA
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mosel Vitelic / ProMOS
# Mosel Vitelic
# Mosel Vitelic
# Nanya
# Nanya
# Nanya
# Nanya
# PSC
# Qimonda
# Infineon / Qimonda
# Spectek
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Elixir Orig
# Elixir Orig
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Promos
# Qimonda
# Spectek
# Elpida
# Elpida
# Elpida
# ESMT
# Infineon / Qimonda
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mitsubishi
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Elpida
# Elpida
# Eplida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mitsubishi
# Mitsubishi
# Nanya
# Nanya
# Nanya
# Qimonda
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Elpdia
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Hitachi / Elpida
# Hitachi / Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mitsubishi
# Nanya
# Nanya
# Nanya
# Toshiba
# UTT - Mira
# Winbond
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# NEC
# Elpida
# Elixir
# Elixir
# Elixir
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Hitachi
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mitsubishi
# Mosel Vitelic
# Nanya
# OEM CEON
# Winbond
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mosel Vitelic
# Nanya
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Elpida
# Elpida
# Elpida
# Elpida
# Hyundai
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Hitachi
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# EliteMT
# EliteMT
# Mosel Vitelic
# Spectek
# ESMT
# PQI
# ESMT
# Mosel Vitelic
# Mosel Vitelic
# Infineon / Qimonda
# Nanya
# Nanya
# Spectek
# Spectek
# Nanya
# Elpida
# Elpida
# Elpida
# Elpida
# NEC
# ---
# Elpida
# Elpida
# Spectek
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Nanya
# Nanya
# Elpida
# Nanya Orig
# Nanya Orig
# Nanya Orig
# Nanya Orig
# Nanya Orig
# Nanya Orig
# Nanya
# Nanya Orig
# Elpida
# Elpida
# ISSI
# ISSI
# ISSI
# Nanya
# Nanya
# Numonyx
# Nanya
# Nanya
# Qimonda
# Qimonda
# Qimonda
# Infineon
# Infineon
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda
# infinion
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Elpida
# Infineon / Qimonda
# Infineon
# Infineon
# Qimonda
# Freescale
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# ISSI
# Winbond
# Nanya
# Elixir
# Elixir
# Zentel
# Elixir
# Zentel
# Elpida
# Zentel
# Zentel
# Zentel
# Elpida
# Zentel
# Elpida
# Zentel
# GBIT
# Zentel
# ICSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ICSI
# ISSI
# Nanya
# Nanya
# Hyundai
# ESMT
# Elixir
# Elixir
# Elixir
# Elixir
# Elpida
# Elpida
# Infineon / Qimonda
# Mira
# Mira
# Mosel Vitelic
# Mosel Vitelic
# OEM AMIC
# PGA
# Qimonda
# Eorex
# Winbond
# Winbond
# Winbond
# Winbond
# Powerchip Semicon
# Mitsubishi
# Elite MT
# Elite MT
# Elpida
# Elpida
# Elpida
# Elpida
# GBIT
# GBIT
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# StarRam
# StarRam
# Winbond
# Winbond
# Winbond
# AMIC (Taiwan)
# Elpida
# Etron
# Etron
# Etron
# ICSI
# ICSI
# ISSI
# Nanya
# Nanya
# Nanya
# OEM ACE
# OEM VT
# PIECEMAKERS
# Vanguard
# Vanguard
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Elite MT
# Eudar
# Elite MT
# Etron
# ESMT
# Etron
# Mosel Vitelic
# Etron
# Elite MT
# Elpida
# EtronTech
# EtronTech
# EtronTech
# EtronTech
# EtronTech
# GBIT
# ISSI
# OEM VT
# StarRam
# Toshiba
# Winbond
# Winbond
# Elite MT
# Eorex
# Elite MT
# Etron
# Etron
# Etron
# Etron
# Fujitsu
# Fujitsu
# Fujitsu
# PIECEMAKERS
# IC Sensors
# ICSI
# ICSI
# Infineon / Qimonda
# ISSI
# Mira
# Mosel Vitelic
# Mosel Vitelic
# Winbond
# Winbond
# Etron
# Etron
# Etron
# Etron
# Etron
# ISSI
# Nanya
# Nanya
# Nanya
# Elpida
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# PIECEMAKERS
# ISSI
# WINBOND
# Winbond
# WINBOND
# ISSI
# Elpida
# Mira
# Elpida
# Elpida
# Nanya
# Nanya
# Nanya
# WINBOND
# Nanya
# ICSI
# ICSI
# ISSI
# Etron
# Powerchip Semicon
# ISSI
# ISSI
# ISSI
# Nanya
# Nanya
# Nanya
# Nanya/Blank
# ISSI
# Elixir
# ISSI
# NANYA
# Elpida
# Winbond
# Winbond
# ICSI
# Winbond
# OEM
# ISSI
# Winbond
# ISSI
# ISSI
# ESMT
# Hyinx
# ICSI
# ISSI
# Elite MT
# Etron
# ICSI
# Infineon / Qimonda
# ICSI
# ICSI
# Mosel Vitelic
# Nanya
# Mosel Vitelic
# Mosel Vitelic
# Mosel Vitelic
# GBIT
# ICSI
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# ISSI
# Infineon / Qimonda
# ISSI
# ISSI
# ISSI
# ISSI
# Mosel Vitelic
# «n¨È
# Nanya
# «n¨È
# Nanya
# Nanya
# Nanya
# Vanguard
# Vanguard
# Winbond
# Elite MT
# Eorex
# GBIT
# AMIC (Taiwan)
# Elite MT
# Elite MT
# Elite MT
# Eorex
# Eorex
# ESMT
# Etron
# ESMT
# ESMT
# Etron
# ESMT
# Etron
# GBIT
# ICSI
# ICSI
# ICSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# Mosel Vitelic
# Nanya
# OKI
# V-Data
# Winbond
# Elite MT
# Elite MT
# Fujitsu
# Fujitsu
# Toshiba
# Toshiba
# Toshiba
# Toshiba
# Winbond
# Winbond
# ADvice
# AMIC
# Esmt
# Elite MT
# Elite MT
# Elite-MT
# ESMT
# ESMT
# ESMT
# Etron
# Fujitsu
# Etron
# GBIT
# Hyundai
# IC Sensors
# ICSI
# ICSI
# ICSI
# ICSI
# ICSI
# ICSI
# ICSI
# ICSI
# ISSI
# ICSI
# ISSI
# ICSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# Mira
# Nanya
# OEM
# OKI
# OKI
# OKI
# OKI
# Ramsway
# Vanguard
# Winbond
# Winbond
# Elpida
# Elpida
# Elpida
# Elpida
# Infineon / Qimonda
# Qimonda
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Elpida (Hitachi)
# Elpida (Hitachi)
# Elpida
# Elpida
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mitsubishi
# Mitsubishi
# Nanya
# Qimonda
# Qimonda
# Qimonda
# Qimonda
# Elpida
# Elpida
# Elpida
# Hitachi
# Hitachi
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda
# Elpida Singapore
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Hitachi
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mitsubishi
# Mitsubishi
# Mosel Vitelic
# Mosel Vitelic
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# Nanya
# NEC (Elpida)
# Nanya
# Spectek
# Toshiba
# Spectek
# Toshiba
# Toshiba
# UTT - Nanya
# UTT
# Winbond
# Elpida
# ETT Winbond
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mitsubishi
# Mitsubishi
# Mitsubishi
# NEC
# Qimonda
# Qimonda
# Elixir
# Elixir
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Eorex
# ESMT
# Eorex
# GBIT
# Hitachi / Elpida
# Hitachi
# Hitachi
# ISSI
# ISSI
# Elpida
# Hyundai
# ICSI
# ICSI
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# ISSI
# ISSI
# ISSI
# Wrong PN
# Mitsubishi [fr mod]
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mosel Vitelic
# Mosel Vitelic
# Mosel Vitelic
# Promos
# Nanya
# Promos
# Nanya
# Nanya
# Promos
# Nanya
# Nanya
# Nanya
# NEC
# OEM
# OEM
# Pointec
# Qimonda
# Qimonda
# Qimonda
# Spectek
# Toshiba
# Toshiba
# Toshiba
# Toshiba
# Toshiba
# UTT - infineon
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Hyundai
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Kinghorse
# Nanya
# Nanya
# NEC
# NEC
# PSC
# Qimonda
# Qimonda
# Spectek
# Spectek
# Toshiba
# Toshiba
# Toshiba
# UTT - Infineon
# Vanguard
# Winbond
# Hyundai
# Infineon / Qimonda
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elixir
# Elixir
# Elixir
# Elpida ett
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# GBIT
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# Mira
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mosel Vitelic
# Nanya
# NEC
# Nanya
# NEC
# OEM
# PQI
# Spectek
# Spectek
# Spectek
# Spectek
# Spectek
# Star
# Toshiba
# Toshiba
# Toshiba
# Toshiba
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# Winbond
# AVL
# Elpida / Hitachi
# Elpida / NEC
# Hitachi
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mosel Vitelic
# Nanya
# Nanya
# Nanya
# Nanya
# NEC
# Toshiba
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# ICSI
# ICSI
# ICSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# Winbond
# ISSI
# Elpida(Hitachi)
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# Elpida
# G-link
# Hitachi
# Infineon / Qimonda
# Mira
# Mira
# Mira
# Mira
# Mira
# Mitsubishi
# Nanya
# NEC
# NEC
# OKI
# OKI
# OKI
# Qimonda
# SMIC
# Spectek
# Spectek
# Spectek
# Spectek
# Toshiba
# Winbond
# Winbond
# Winbond
# Elpida
# Elpida
# G-Link
# GBIT
# ICSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# Mitsubishi
# StarRam
# V-data
# Elite MT
# ISSI
# ISSI
# Mosel Vitelic
# Nanya
# Nanya
# Nanya
# NEC
# NEC
# OEM ACE
# OKI
# StarRam
# Alliance
# Mosel Vitelic
# ICSI
# Toshiba
# Etron
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# QIMONDA
# QIMONDA
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# Elite MT
# Elite MT
# Elixir
# Elite MT
# Elite MT
# Elite MT
# Elite MT
# Etron
# Etron
# Etron
# Mosel Vitelic
# Winbond
# Elite MT
# Elpida
# ICSI
# OEM PSC
# OEM PSC
# OEM TM
# OEM TMC
# OEM TMC
# StarRam
# Vanguard
# Winbond
# Winbond
# ICSI
# ICSI
# Winbond
# Elpida
# Elpida
# Fujitsu
# G-link
# G-link
# ICSI
# ICSI
# Linksmart
# Mosel Vitelic
# Sanyo
# Star
# Star
# TMC
# Qimonda
# Elixir
# Elixir
# Winbond
# Alliance Memory
# Toshiba
# Infineon / Qimonda
# Hyundai (LGS)
# Toshiba
# Toshiba
# Hyundai
# OKI
# NEC
# OKI
# Hitachi
# Infineon / Qimonda
# Infineon / Qimonda
# Mitsubishi
# Hitachi
# Infineon / Qimonda
# Mitsubishi
# Elpida(NEC)
# Hyundai
# Infineon / Qimonda
# Mitsubishi
# NEC
# NEC
# NEC
# Toshiba
# Elpida
# Hyundai
# Infineon / Qimonda
# Infineon / Qimonda
# Mitsubishi
# NEC
# Elpida(Hitachi)
# Elpida
# Hitachi
# Hitachi, Japan
# Hyundai
# Hyundai
# Infineon / Qimonda
# Infineon / Qimonda
# Nanya
# NEC China
# NEC
# Toshiba
# Toshiba
# Fujitsu
# Fujitsu
# Hitachi
# Hyundai
# Hyundai
# Hyundai
# Infineon / Qimonda
# Mitsubishi
# Elpida(Hitachi)
# Elpida
# Hitachi
# Hyundai (LGS)
# Hyundai
# Hyundai
# Hyundai
# Infineon / Qimonda
# Infineon / Qimonda
# Qimonda
# Mitsubishi
# Mitsubishi
# NEC
# NEC
# NEC
# NEC
# Toshiba
# Toshiba
# Toshiba
# Fujitsu
# Fujitsu, Japan
# Hitachi
# Hitachi
# Hitachi
# Hitachi, Japan
# Hyundai(LG)
# Hyundai(LGS)
# Hyundai(LGS)
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# IBM
# IBM
# Infineon / Qimonda
# Infineon / Qimonda
# Infineon / Qimonda
# Mitsubishi
# Mosel Vitelic
# Nanya
# Nanya
# Nanya
# NEC
# NEC
# NEC
# NEC
# Toshiba
# Toshiba
# Elpida(Hitachi)
# Elpida
# Fujitsu
# Fujitsu
# Fujitsu
# Fujitsu
# Fujitsu
# Hyundai
# Infineon / Qimonda
# Infineon / Qimonda
# ISSI
# ISSI
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mosel Vitelic
# Nanya
# Nanya
# NEC / Elpida
# NEC
# NEC
# NEC
# NEC
# NEC/Elpida
# Toshiba
# Toshiba
# NEC
# NEC
# Fujitsu
# NEC
# NEC
# NEC
# Toshiba
# Toshiba
# Toshiba
# Fujitsu
# Hyundai
# NEC
# Alliance
# Elite MT
# Fujitsu
# Hyundai (LG)
# Mitsubishi
# NEC
# NEC
# NEC
# NEC
# NEC
# NEC
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# Siemens
# Siemens
# Vanguard
# Winbond
# NEC
# NEC
# NEC
# Fujitsu, Japan
# Hyundai(LG)
# NEC
# Toshiba, Jap
# Goldstar
# Hyundai
# NEC
# OKI
# NEC
# NEC
# NEC
# Toshiba
# Fujitsu
# Hitachi
# NPNX
# Siemens
# Toshiba
# Elpida(NEC)
# Goldstar
# Hitachi
# Siemens
# Elpida
# Elpida
# Elpida
# Elpida
# Toshiba
# Toshiba
# ISSI
# ISSI
# NEC
# OKI
# OKI
# OKI
# Elpida
# Elpida
# Infineon / Qimonda
# G Link
# Siemens
# Hitachi
# Hitachi
# Hitachi
# Hitachi / Elpida
# Hitachi
# Hitachi
# Hitachi
# Mitsubishi
# Mitsubishi
# Mitsubishi
# NEC
# NEC
# NEC
# OEM Star
# StarRam
# Hitachi / Elpida
# Hitachi
# Hitachi
# Hitachi
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mitsubishi
# NEC
# NEC
# NEC
# Toshiba
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hyundai
# Hyundai
# NEC
# NEC
# Hitachi / Elpida
# Hitachi
# Hitachi
# Hyundai
# Hitachi Korea
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mosel Vitelic
# Toshiba
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hyundai(LGS)
# Hyundai
# Hyundai
# Mitsubishi
# Mitsubishi
# Mitsubishi
# NEC
# NEC
# NEC/ 99
# Samaung
# Samaung
# Samaung
# Toshiba
# Goldstar
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hyundai (LGS)
# Hyundai
# Mitsubishi
# Mitsubishi
# Mitsubishi
# NEC
# OKI
# OKI
# OKI
# Samaung
# Toshiba
# Toshiba
# ISSI
# Fujitsu
# Hyundai
# Hyundai
# Hyundai
# Vanguard
# Hitachi
# Hyundai
# Mitsubishi
# Mitsubishi
# Mosel Vitelic
# Nanya
# Nanya
# NEC Singapore
# NEC
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI/00+
# Siemens
# Siemens
# Toshiba
# UTRON
# ACE
# Fujitsu
# Goldstar
# OEM Golf
# OKI
# StarRam
# Goldstar
# Goldstar
# Hyundai
# Alliance
# Alliance
# ESMT
# Hitachi
# Vanguard
# Vanguard
# Hitach
# Mitsubishi
# Fujitsu
# Goldstar
# Hitachi
# Hitachi
# Hitachi
# Hyundai [LGS]
# Hyundai
# NEC
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI/ 99+
# Toshiba
# Toshiba
# Toshiba
# Hyundai
# Texas Instrument
# NEC
# Hitachi
# Hitachi
# Goldstar
# Hyundai [LGS]
# Hyundai [LGS]
# Hyundai
# Hyundai
# Hyundai
# Mitsubishi
# Alliance
# Alliance
# Alliance
# Alliance
# Alliance
# Alliance
# Alliance
# Alliance
# Alliance
# Alliance
# Fujitsu
# Goldstar
# Goldstar
# Goldstar
# Goldstar
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Infineon / Qimonda
# Infineon / Qimonda
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mitsubishi/98+
# NEC
# NEC
# NEC
# NEC
# NPNX
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI/00+
# OKI/00+
# Siemens
# Texas Instruments
# TM
# Toshiba
# Toshiba
# Vanguard
# Vanguard
# Toshiba
# Alliance
# Alliance
# Alliance
# Fujitsu
# Fujitsu
# Goldstar
# Goldstar
# Hyundai
# ICSI
# Infineon / Qimonda
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# OKI
# OKI
# OKI
# OKI/00+
# Elite MT
# Elite MT
# G-Link
# TM
# ICSI
# ICSI
# NEC
# Vanguard
# Mosel Vitelic
# Goldstar
# Fujitsu
# Fujitsu
# Hitachi
# Hyundai
# Hyundai
# Mitsubishi
# Texas Instruments
# ICSI
# Mosel Vitelic
# ISSI
# Alliance
# Alliance
# Alliance
# Alliance
# Alliance
# Alliance
# Etron
# Goldstar
# Hitachi
# ISSI
# ISSI
# ISSI
# NEC
# NEC
# NEC
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# Toshiba
# Alliance
# Alliance
# Hitachi
# ISSI
# ISSI
# Mosel Vitelic
# NPNX
# OKI
# OKI
# OKI
# OKI
# OKI
# Toshiba/98+
# Alliance
# Mosel Vitelic
# OKI
# OKI/00+
# G-Link
# Mosel Vitelic
# OKI
# Alliance
# Alliance
# Alliance
# Alliance
# AMIC
# Elite MT
# Elite MT
# Elite-MT
# Elite-MT
# Elite-MT
# IC Sensors
# ICSI
# ICSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# TM
# Mosel Vitelic
# Mosel Vitelic
# Etron
# Mosel Vitelic
# Hyundai(LGS)
# OKI
# OKI
# OKI
# Slicon Magic
# OKI
# OKI
# OKI
# OKI
# Mitsubishi
# Toshiba
# Toshiba
# Mosel Vitelic
# Goldstar
# Hitachi
# Hyundai
# Mitsubishi
# NEC
# Hyundai
# Hyundai
# Hitachi
# Hitachi
# Mitsubishi
# NEC
# Mitsubishi
# ICSI
# GoldStar
# Hitachi
# Mitsubishi
# Hitachi
# Mitsubishi
# Texas Instruments
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hyundai(LGS)
# Hyundai(LGS)
# Hyundai
# Mitsubishi
# Mitsubishi
# Mitsubishi
# NEC
# NEC
# OKI
# OKI
# OKI
# Siemens
# Toshiba
# Alliance
# Fujitsu/99+
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hyundai [LGS]
# Hyundai(LG)
# Hyundai
# Hyundai
# Hyundai
# Hyundai
# Infineon / Qimonda
# ISSI
# Mitsubishi
# Mitsubishi
# Nanya
# Nanya
# Nanya
# NEC
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# Toshiba
# VANGUARD
# Alliance
# Hitachi
# Hyundai
# Mitsubishi
# Toshiba
# Mitsubishi
# Siemens
# Toshiba
# ISSI
# OKI
# OKI
# OKI
# Hitachi / Elpida
# Mitsubishi
# Vanguard
# Mitsubishi
# Hitachi
# Hitachi
# Mitsubishi
# NEC
# Siemens
# Fujitsu
# Fujitsu
# Hitachi
# Hitachi
# Hitachi
# Hyundai
# LGS OEM
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# Hyundai
# Mitsubishi
# Motorola
# Siemens
# Toshiba
# Fujitsu
# Hitachi
# Hitachi
# Hitachi
# Hitachi/98
# Hyundai
# LGS
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# Siemens
# OKI
# Hitachi 400mil
# Mitsubishi
# Fujitsu
# Fujitsu
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hyundai(LGS)
# Hyundai
# ISSI
# ISSI
# Mitsubishi
# Mitsubishi
# Mitsubishi
# NEC
# NEC
# NEC
# NEC
# OKI
# OKI
# OKI
# OKI
# Toshiba
# ISSI
# Infineon / Qimonda
# Hyundai
# Mitsubishi
# Mitsubishi
# Toshiba
# Goldstar
# Goldstar
# Hitachi
# Hitachi/Elpida
# Hyundai [LGS]
# Hyundai [LGS]
# Hyundai
# Mitsubishi
# NEC
# OKI
# OKI
# Vanguard
# Alliance
# Alliance
# Alliance
# Alliance
# Elpida
# Goldstar
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hyundai
# Hyundai
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# Mitsubishi
# Mitsubishi
# NEC
# NEC
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# Siemens
# Toshiba
# Toshiba
# Toshiba
# Toshiba
# Hitachi
# Hyundai [LGS]
# Hyundai
# Hyundai
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mitsubishi
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# ICSI
# ISSI
# ISSI
# ISSI
# ISSI
# ISSI
# Mosel Vitelic
# Hitachi
# Hitachi
# OKI
# Toshiba
# Toshiba
# Fujitsu
# NEC
# Siemens / Infineon
# Fujitsu
# Fujitsu
# Fujitsu
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi,Japan/00+
# Toshiba
# Mitsubishi
# OKI
# OKI
# OKI
# OKI
# OKI
# Texas Instruments
# Fujitsu
# Fujitsu
# Goldstar
# Hitachi
# Hitachi
# Hitachi
# Hitachi,Japan/00+
# Hitachi/99+
# Hyundai
# Infineon / Qimonda
# ISSI
# Mitsubishi
# Mitsubishi
# Mitsubishi
# Mitsubishi
# NEC
# NEC
# NEC
# NEC
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# Siemens / Infineon
# Texas Instruments
# Infineon / Qimonda
# Fujitsu
# Hitachi
# ICSI
# ICSI
# NEC
# NEC
# Hitachi
# Hitachi
# Toshiba
# Toshiba
# Fujitsu
# Hitachi
# Mitsubishi
# Motorola
# Texas Instruments
# Fujitsu
# Hyundai
# NPNX
# Hitachi
# Hitachi
# Mitsubishi
# OKI
# Hitachi
# Hitachi
# NEC
# NEC
# Hitachi
# Hitachi
# Motorola
# NEC
# NEC
# NEC
# NEC
# NEC
# NEC
# OKI
# OKI
# OKI
# Toshiba
# ISSI
# LGS
# Motorola
# OKI
# OKI
# Fujitsu
# Hitachi
# Hitachi
# Fujitsu
# Fujitsu
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hyundai
# NEC
# NEC
# NEC
# NEC
# OKI
# Alliance
# Alliance
# Alliance
# Alliance
# Fujitsu
# Hitachi
# Hitachi
# Hitachi
# Hitachi
# Hyundai
# ISSI
# ISSI
# ISSI
# Mosel Vitelic
# NEC
# NEC
# NEC
# NPNX
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# OKI
# Siemens/98+
# Alliance
# Mosel Vitelic
# Mosel Vitelic
# NPNX
# NPNX
# OKI
# Mosel Vitelic
# Alliance
# ISSI
# ISSI
# ISSI
# OKI
# Hitachi
# NEC
# OKI
# OKI
# OKI
# OKI
# Hitachi
# OKI
# Fujitsu
# Fujitsu
# Fujitsu
# Fujitsu
# LG
# OKI
# OKI
# OKI
# OKI
# OKI
# Fujitsu
# Fujitsu
# Fujitsu
# Fujitsu
# Fujitsu
# Goldstar
# OKI
# OKI
# Siemens
# Toshiba
# OKI
# Hitachi
# Fujitsu
# Toshiba
# Mitsubishi
# NEC
# OKI
# Infineon / Qimonda
# Hyundai
# Mosel Vitelic
# Mosel Vitelic
# Mosel Vitelic
# Mosel Vitelic
# Toshiba
# Mitsubishi
# OKI
# Hitachi
# OKI
# Fujitsu
# Infineon / Qimonda
# Elpida
# Elpida
# Elpida
# Hyundai / LGS
# Hyundai(LGS)

# %% [markdown]
# # 2 - Functions to use
# There are 5 major functions for performing the actual matching. Only 3 are extensively used, as we want to process full strings, and not stop at the first matched pattern.
#
# <div id="content" class="container">
# <div class="row"><div class="col-md-9"><h1 class="title"></h1>
# <table class="table table-striped table-bordered table-hover table-condensed">
#
# <colgroup>
# <col  class="left">
# <col  class="left">
# <col  class="left">
# </colgroup>
#
# <tbody>
# <tr>
# <td class="text-left"><code>re.search(regexp, string, FLAGS)</code></td>
# <td class="text-left">Find the first occurence of the regular experssion</td>
# <td class="text-left"></td>
# </tr>
#
# <tr>
# <td class="text-left"><code><font color=red>re.findall(regexp, string, FLAGS)</font></code></td>
# <td class="text-left">Find all occurences of the regular expression</td>
# <td class="text-left">Returns a list: <code>[match1, match2, match3]</code></td>
# </tr>
#
# <tr>
# <td class="text-left"><code>re.match(regexp, string, FLAGS)</code></td>
# <td class="text-left">Match from the beggning</td>
# <td class="text-left"></td>
# </tr>
#
# <tr>
# <td class="text-left"><code><font color=red>re.fullmatch(regexp, string, FLAGS)</font></code></td>
# <td class="text-left">Match from beginning to end</td>
# <td class="text-left">Returns either: <code>None</code> or a match, whose contents can be accessed with <code>mg.group()</code></td>
# </tr>
#
# <tr>
# <td class="text-left"><code><font color=red>re.sub(regexp, replacement, string, FLAGS)</font></code></td>
# <td class="text-left">Substitutes the regular experssion for pattern of choice</td>
# <td>Returns a string with implemented substitutions: <code>substituted_string</code></td>
# </tr>
#
# <tr>
# <td class="text-left"><code><font color=red>re.IGNORECASE</font></code></td>
# <td class="text-left">Use as a <code>FLAG</code> to ignore lower and uppercase differences</td>
# <td class="text-left"></td>
# </tr>
# </tbody>
# </table>

# %%
########################################
# 🍏 It is possible for certain entries to have multiple brands
#     If this is the case, then perform a findall search
########################################
# 1 - prepare data
brand = ["Elpida", "Qimonda", "Infineon / Qimonda"]

regexp = "SK Hynix|Samsung|Hynix|Micron|Elpida|Qimonda|Infineon"

for idx, i in enumerate(brand):

    # 3 - try to match one of the brands
    mg = re.findall(regexp, i, re.IGNORECASE)
    
    if(mg is None):
        # 4 - print if brand did not exist
        print(i)
    else:
        brand[idx] = "-".join(mg)

########################################
# 📔 Modify the previous exercise to include multiple brands
########################################
# Out:
# ['Elpida', 'Qimonda', 'Infineon-Qimonda']

# %%
########################################
# 🍏 re.fullmatch would be used for verfification of a whole string
########################################
# 1 - load in data
example = ["1243GF2222", "124gF2222"]

# 2 - part number format is: 4numbers-3AtoZ-4numbers
regexp = "\d{4,}[A-Z]{2,}\d{4}"

for i in example:
    mg = re.fullmatch(regexp, i)
    if(mg is None):
        print("✘ Error with\t", i)
# Out:
# ✘ Error with	 124gF2222

# %% [markdown]
# # Repetitions
# Occasionally, one wants the specify a pattern where a certain number of characters is repeated. For example, to match all of the following speeds (that need to be labelled as description)
#
# <center>800MHz, speed 600 kHz, 30 mHz, 100-Mhz</center>
#
# ***
# <table class="table table-striped table-bordered table-hover table-condensed">
#
# <colgroup>
# <col  class="left">
#
# <col  class="left">
# </colgroup>
# <thead>
# <tr>
# <th scope="col" class="text-left"><b>Repetition</b></th>
# <th scope="col" class="text-left"><b>Description</b></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="text-left"><code>"*"</code></td>
# <td class="text-left">Matches 0 or more of the preceding RE</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"+"</code></td>
# <td class="text-left">Matches 1 or more of the preceding RE.</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"?"</code></td>
# <td class="text-left">Matches 0 or 1  of the preceding RE.</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"{m,n}"</code></td>
# <td class="text-left">Matches from m to n repetitions of the preceding RE.</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"*?", "+?", "??", "{m,n}?"</code></td>
# <td class="text-left"><b><font color=red>Non-greedy</font></b> versions of the previous three characters</td>
# </tr>
# </tbody>
# </table>
# <b><font color=red>Non-greedy means the minimal amount will be matched (not used commonly in our workflow)</font></b>

# %%
########################################
# 🍏 Example showing how the re.subn function can be used to remove junk in square brackets that occurs in some of the brands
########################################

# 1 - prepare data
example = ["Kingston Orig [1Gx8 16C]", "Crucial Orig", "Hynix Orig [1Gx8 8C]", "Hynix Orig [1Gx8 8C]", "Hynix Orig [512Mx64 8C]", "Samsung Orig [512Mx16 4C]", "Kingston retail", "Samsung Orig [512Mx16 4C]", "Samsung Orig [512Mx8 8C]"]

# 2 -regexp to eleminate square brackets and everything inside them
# . matches any characters
# * matches any number of times
regexp = "\[.*\]"

for i in example:
    mg = re.sub(regexp, "", i)
    print(mg)
# Out:
# Kingston Orig
# Crucial Orig
# Hynix Orig
# Hynix Orig
# Hynix Orig
# Samsung Orig
# Kingston retail
# Samsung Orig
# Samsung Orig

# %%
########################################
# 📔 Redo the brand check, but this time go from the opposite end, trying to remove all the junk
########################################
# 1 - load the data
brand = read_pickle("datasets/DRAM_OfferScraperOutput.pkl")['Brand']

# 2 - Use regular experssions to spell out common junk that needs to be removed
regexp = "🍄🍄🍄🍄"

for idx, i in enumerate(brand):

    # 3 - eliminate the junk
    mg = re.sub(regexp, "", i)
    print(mg)

# %%
########################################
# 🍏 Example catching word errors
########################################
# A common typo can be handled by allowing the incorrect rearrangment of letters to allow both Intel ↔ Inetl

# 1 - load the data
brand = ["Intel", "Inetl", "AMD"]

# 2 - Use regular experssions to explicitly spell out brand that are accepted
regexp = "In[te]{2}l|AMD"

for idx, i in enumerate(brand):

    # 3 - try to match one of the brands
    mg = re.search(regexp, i, re.IGNORECASE)
    
    if(mg is None):
        # 4 - print if brand did not exist
        print("✘ Error with", i)
    else:
        brand[idx] = mg.group()

print(brand)
########################################
# 📔 Simplify the brand search in the previous cells e.g. \d\d\d\d → \d{4}
########################################
# Out:
# ['Intel', 'Inetl', 'AMD']

# %%
########################################
# 🍏 Example of matching frequencies
########################################
frequencies_to_match = ["800MHz", "speed 600 kHz", "30 mHz", "100-Mhz", "100", "2666Hz"]

# 1 - look for: 2-3numbers + maybe a white space + khz or mhz
regexp = r"\b\d{2,3}[\s-]?[km]hz" 

for i in frequencies_to_match:
    mg =  re.findall(regexp, i, re.IGNORECASE)
    print(mg, "\t\t←\t\t", i)
# Out:
# ['800MHz'] 		←		 800MHz
# ['600 kHz'] 		←		 speed 600 kHz
# ['30 mHz'] 		←		 30 mHz
# ['100-Mhz'] 		←		 100-Mhz
# [] 		←		 100
# [] 		←		 2666Hz

# %%
########################################
# 📓 Ammend the regular expression below, to double check that prices are of the correct format
######################################## 
# Call          →       Call
# Bid           →       Bid
# Sold out      →       Sold out
# ---           →       NA

# 1 - load data and prepare list of verified prices
prices = read_pickle("datasets/DRAM_OfferScraperOutput.pkl")['Price']

# 2 - regular expression to allow only certain prices
regexp = "USD\d{1}\.\d{2}"

# 3 - move through the list and try to find a match
for idx, i in enumerate(prices):
    mg = re.fullmatch(regexp, i, re.IGNORECASE)
    
    if (mg is None):
        # 4 - print elements which did not fit the regexp
        print(i)
        prices[idx] = "INCORRECT FORMAT"
# Out:
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# Bid
# ---
# Sold Out
# Call
# Call
# Call
# Bid
# Call
# Call
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# Call
# Call
# Bid
# Call
# Call
# Call
# Call
# Bid
# Bid
# Call
# ---
# Call
# Bid
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# Bid
# Bid
# ---
# ---
# Call
# Bid
# ---
# Call
# ---
# Call
# Call
# Bid
# Call
# Call
# Call
# ---
# Call
# Bid
# ---
# Call
# Bid
# Sold Out
# Call
# Call
# Bid
# Bid
# ---
# Sold Out
# Bid
# Call
# Bid
# Call
# Call
# ---
# Bid
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# Bid
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Bid
# Call
# Call
# Call
# Call
# ---
# Bid
# ---
# Call
# ---
# Call
# Call
# ---
# Call
# ---
# Bid
# Bid
# ---
# Bid
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Bid
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# Bid
# ---
# Call
# Call
# Call
# ---
# Bid
# Bid
# ---
# Bid
# ---
# Call
# Call
# Call
# ---
# ---
# Bid
# Bid
# Bid
# Call
# Bid
# Bid
# Bid
# Call
# Call
# Call
# Bid
# Call
# Call
# Call
# Bid
# Call
# Call
# ---
# ---
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# Bid
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# Call
# ---
# Bid
# Call
# ---
# ---
# Bid
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Bid
# Call
# Call
# Call
# Call
# Bid
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# Call
# ---
# Call
# ---
# Bid
# Bid
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Bid
# Bid
# ---
# Call
# USD10.95
# ---
# Call
# Bid
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Bid
# Bid
# Bid
# Call
# ---
# Call
# Bid
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# Call
# Bid
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Bid
# Bid
# ---
# ---
# ---
# Bid
# Bid
# Call
# Bid
# ---
# ---
# Bid
# ---
# Bid
# ---
# Call
# Bid
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# Bid
# Bid
# Call
# Bid
# Bid
# ---
# ---
# Bid
# ---
# Call
# ---
# ---
# ---
# ---
# Bid
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# ---
# ---
# Bid
# ---
# ---
# Call
# Call
# Bid
# ---
# Call
# ---
# Bid
# ---
# ---
# Call
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# USD13.00
# Call
# ---
# ---
# ---
# USD14.70
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# ---
# ---
# ---
# Call
# Call
# USD15.45
# USD21.63
# Call
# USD24.50
# Call
# ---
# Bid
# USD12.36
# Call
# Call
# Call
# ---
# ---
# USD16.30
# Call
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# USD13.00
# ---
# Call
# USD12.50
# USD12.30
# ---
# ---
# Call
# USD14.20
# Call
# Call
# ---
# Call
# Call
# USD11.33
# USD12.00
# Bid
# USD13.90
# Bid
# ---
# ---
# Call
# Call
# Call
# ---
# USD10.82
# Bid
# Bid
# Call
# USD13.70
# ---
# ---
# Call
# Bid
# Call
# Call
# Call
# ---
# Call
# Bid
# Call
# Call
# Bid
# Call
# Bid
# Call
# Bid
# ---
# Call
# Call
# Call
# Call
# Call
# Sold Out
# ---
# Bid
# Call
# Bid
# USD26.00
# Sold Out
# USD12.50
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# Bid
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# Bid
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Bid
# Call
# Call
# Call
# Call
# Bid
# Call
# Bid
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Bid
# ---
# ---
# ---
# ---
# Bid
# Bid
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# Bid
# Sold Out
# ---
# Bid
# Call
# Call
# Call
# Call
# Call
# Bid
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Bid
# Sold Out
# Call
# Bid
# Bid
# Bid
# ---
# ---
# Bid
# Call
# Bid
# Call
# Call
# USD13.12
# Call
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# Bid
# Bid
# Bid
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# ---
# USD16.00
# USD29.00
# USD15.60
# ---
# ---
# Call
# Call
# Call
# Bid
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# USD20.08
# ---
# ---
# ---
# ---
# ---
# Bid
# Call
# USD34.00
# Call
# Bid
# Bid
# Call
# Call
# Call
# ---
# USD26.57
# Call
# ---
# Call
# Call
# ---
# USD10.61
# ---
# Call
# Call
# Call
# Call
# Bid
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# Bid
# Call
# Bid
# Call
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# Call
# ---
# Call
# Call
# ---
# Call
# Bid
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Bid
# ---
# ---
# Call
# Call
# Bid
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Bid
# Call
# Call
# Bid
# Bid
# Call
# Bid
# Bid
# Bid
# ---
# ---
# Call
# ---
# Call
# ---
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# Sold Out
# Call
# Call
# ---
# Call
# Bid
# ---
# Call
# Bid
# Call
# ---
# Call
# Bid
# Call
# Call
# ---
# ---
# Bid
# USD12.50
# USD12.00
# ---
# USD12.88
# Bid
# ---
# Bid
# Bid
# USD11.20
# USD14.20
# Call
# ---
# Call
# Call
# Call
# Call
# Bid
# Call
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# Bid
# ---
# ---
# Call
# Call
# Bid
# ---
# Call
# Bid
# Bid
# ---
# Call
# Call
# Call
# Bid
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# Call
# Call
# Call
# Call
# Call
# Bid
# ---
# Bid
# ---
# ---
# ---
# ---
# Bid
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# Bid
# ---
# Call
# Call
# ---
# ---
# Call
# ---
# Call
# Bid
# ---
# Call
# ---
# ---
# Bid
# ---
# Call
# ---
# Call
# ---
# Bid
# Call
# Call
# Call
# Bid
# Call
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Bid
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# Bid
# Call
# Bid
# Bid
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# Bid
# Bid
# ---
# ---
# Call
# Call
# Call
# Bid
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Bid
# Call
# ---
# ---
# Bid
# ---
# Call
# ---
# Call
# ---
# Bid
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# Bid
# Call
# USD20.08
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# USD12.36
# Bid
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# Sold Out
# ---
# ---
# Bid
# Sold Out
# ---
# ---
# Call
# Bid
# Bid
# ---
# Call
# Bid
# ---
# ---
# ---
# Call
# Bid
# Call
# Call
# ---
# Call
# Bid
# ---
# Call
# ---
# Call
# Bid
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# Bid
# Call
# Bid
# Call
# Call
# Call
# Bid
# Sold Out
# Call
# Bid
# Bid
# Call
# ---
# USD63.00
# USD80.00
# USD23.10
# ---
# ---
# Bid
# Bid
# Call
# Call
# Call
# Bid
# ---
# ---
# ---
# Sold Out
# Call
# Call
# Call
# Call
# USD31.50
# Call
# Call
# Call
# ---
# Call
# Bid
# ---
# Call
# ---
# ---
# ---
# Bid
# ---
# Call
# Bid
# ---
# Bid
# Call
# Bid
# Call
# Call
# Call
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# Call
# Call
# USD11.00
# ---
# Call
# ---
# Bid
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# Bid
# Call
# Bid
# ---
# Call
# Call
# Call
# ---
# ---
# Bid
# Call
# Bid
# ---
# Call
# ---
# ---
# ---
# Bid
# Call
# Call
# Call
# Bid
# Call
# Call
# Bid
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Bid
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Bid
# Call
# Call
# Bid
# Call
# Call
# Bid
# Bid
# Call
# Call
# Call
# Call
# ---
# Bid
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# Bid
# Call
# Call
# ---
# Call
# Bid
# ---
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# Call
# ---
# Bid
# ---
# USD11.31
# Bid
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# Sold Out
# ---
# Call
# Call
# Bid
# Bid
# ---
# ---
# Call
# ---
# ---
# Bid
# Call
# Call
# Bid
# Call
# ---
# Bid
# Bid
# Call
# Bid
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# Bid
# Call
# Call
# Sold Out
# ---
# Call
# Bid
# Call
# ---
# Bid
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# Call
# Call
# Bid
# Call
# Bid
# Call
# ---
# Call
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# Call
# Bid
# ---
# Call
# Call
# Bid
# USD22.40
# ---
# ---
# ---
# Bid
# Call
# ---
# Call
# Call
# Call
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Bid
# ---
# Bid
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# Call
# ---
# Call
# Call
# ---
# Bid
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# Bid
# Call
# ---
# ---
# Call
# Call
# ---
# Call
# Bid
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# Bid
# ---
# Bid
# Bid
# Bid
# Bid
# Call
# ---
# ---
# Call
# Bid
# Bid
# Call
# Call
# Call
# Bid
# Call
# Call
# ---
# Bid
# Call
# Bid
# ---
# ---
# ---
# Bid
# Call
# Call
# Bid
# Call
# Bid
# Bid
# ---
# Call
# Call
# Call
# ---
# Bid
# Call
# ---
# Call
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Bid
# Sold Out
# Call
# ---
# Call
# ---
# ---
# Bid
# Call
# ---
# Call
# ---
# Call
# Bid
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# Bid
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# ---
# Bid
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Bid
# ---
# Call
# ---
# Call
# Bid
# ---
# Bid
# ---
# Call
# Call
# ---
# ---
# ---
# Bid
# ---
# ---
# Bid
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Sold Out
# Bid
# Bid
# Bid
# ---
# ---
# Call
# Call
# Call
# Bid
# ---
# Call
# Bid
# Call
# Bid
# Call
# ---
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# Call
# Bid
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# Bid
# ---
# Call
# Call
# Call
# Bid
# Bid
# Call
# Call
# Bid
# Call
# Call
# Call
# Call
# Bid
# ---
# Bid
# Call
# Bid
# Call
# ---
# ---
# Call
# Bid
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# Bid
# Call
# Call
# Call
# ---
# Call
# Call
# ---
# Bid
# Call
# Call
# ---
# Call
# Call
# Bid
# Call
# ---
# ---
# ---
# Call
# Bid
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# Call
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Bid
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# Bid
# Call
# Bid
# Call
# ---
# Bid
# Call
# Call
# Bid
# Bid
# Bid
# Bid
# Call
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# Sold Out
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# ---
# ---
# Call
# Call
# Call
# USD16.00
# Call
# ---
# ---
# Bid
# Bid
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Bid
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Bid
# Call
# Call
# Call
# Bid
# Bid
# Bid
# ---
# Call
# Call
# ---
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# Bid
# ---
# Call
# ---
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# Bid
# ---
# ---
# Call
# ---
# Call
# Call
# Bid
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# Bid
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# Bid
# Bid
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# Call
# Call
# ---
# Bid
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# Call
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# ---
# ---
# Bid
# Call
# Bid
# Call
# Call
# Call
# Call
# Bid
# Call
# Call
# Bid
# Call
# Call
# Call
# Bid
# Call
# Call
# Call
# Bid
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# ---
# ---
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# Bid
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# Bid
# Bid
# Call
# Call
# Call
# ---
# Call
# Bid
# Sold Out
# Call
# Bid
# ---
# ---
# Call
# Bid
# Bid
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# Bid
# Call
# ---
# Bid
# ---
# Call
# Call
# Bid
# Call
# Call
# Sold Out
# Call
# Call
# Bid
# Bid
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Bid
# Call
# ---
# Call
# Call
# Bid
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# Sold Out
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# Bid
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# Call
# Bid
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# ---
# Bid
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# Bid
# Call
# ---
# Bid
# Call
# Call
# Call
# Bid
# ---
# Call
# Bid
# ---
# Call
# ---
# Call
# Call
# Call
# Bid
# Call
# ---
# Call
# Sold Out
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Bid
# Call
# Call
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# ---
# Call
# ---
# Bid
# ---
# Call
# Call
# Bid
# Call
# Call
# ---
# ---
# Call
# Bid
# Bid
# Call
# ---
# Call
# Call
# Call
# ---
# ---
# Sold Out
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# Call
# Call
# Call
# Bid
# Call
# ---
# Call
# ---
# ---
# Bid
# Call
# Bid
# Bid
# ---
# Bid
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# ---
# Bid
# Call
# ---
# Call
# Bid
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# Bid
# Call
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# Call
# Call
# USD33.80
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# Bid
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# Call
# ---
# Call
# Call
# Bid
# ---
# Bid
# ---
# Sold Out
# Call
# Call
# Bid
# Call
# Call
# Call
# Bid
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# ---
# ---
# Call
# Bid
# Sold Out
# Call
# Call
# Call
# Call
# Bid
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Sold Out
# Bid
# Call
# Sold Out
# Bid
# ---
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# USD1.035
# ---
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# Bid
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# Bid
# Bid
# Call
# Call
# Call
# Bid
# Call
# ---
# Call
# Call
# ---
# Bid
# Bid
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# Bid
# Call
# Call
# ---
# ---
# Call
# Bid
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# Bid
# Call
# Bid
# Call
# Call
# Call
# ---
# Bid
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# Call
# ---
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Bid
# Call
# Call
# Bid
# ---
# Call
# ---
# Bid
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# Bid
# Bid
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# USD21.00
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# Bid
# ---
# Call
# Call
# ---
# Call
# Bid
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Bid
# Call
# Bid
# Call
# Call
# USD25.50
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Bid
# Call
# Bid
# ---
# ---
# Call
# Bid
# Call
# Call
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# Bid
# Bid
# Bid
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Bid
# Call
# ---
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# Bid
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# Bid
# Call
# Bid
# Bid
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Bid
# ---
# Call
# Call
# Call
# Bid
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# Bid
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# ---
# ---
# ---
# ---
# Bid
# Call
# ---
# Call
# ---
# ---
# ---
# Bid
# ---
# Bid
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# Sold Out
# Bid
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# USD15.00
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# ---
# ---
# Sold Out
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# Bid
# Bid
# Bid
# Call
# Bid
# ---
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# Bid
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# Call
# Sold Out
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# Call
# Call
# Call
# Bid
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Bid
# Call
# Call
# Bid
# Call
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# Bid
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Bid
# Bid
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# Bid
# ---
# Bid
# ---
# Bid
# Bid
# Call
# ---
# Bid
# Call
# ---
# Bid
# Call
# Bid
# Call
# Call
# Call
# Call
# ---
# Bid
# ---
# Call
# Sold Out
# Call
# Call
# Call
# ---
# ---
# Bid
# Bid
# Call
# Call
# Bid
# Call
# Call
# Call
# ---
# Call
# Bid
# Call
# ---
# Bid
# ---
# ---
# ---
# Call
# Call
# Bid
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# ---
# Call
# ---
# ---
# Bid
# ---
# Bid
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# Bid
# ---
# Call
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# Call
# ---
# Bid
# Call
# Call
# Call
# ---
# Call
# Call
# Bid
# ---
# Bid
# Call
# ---
# Bid
# ---
# USD41.00
# ---
# Call
# ---
# ---
# Call
# Bid
# Bid
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Sold Out
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# Bid
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# Bid
# Bid
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# Call
# Call
# Bid
# Bid
# ---
# ---
# Call
# Bid
# ---
# Bid
# ---
# Call
# Bid
# ---
# ---
# Bid
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# Call
# Bid
# ---
# ---
# Bid
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# ---
# Sold Out
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Bid
# Call
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# Bid
# ---
# Call
# ---
# Bid
# Call
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# USD57.75
# ---
# USD57.75
# ---
# Call
# ---
# Call
# ---
# ---
# Bid
# Call
# Call
# Call
# Bid
# Call
# Call
# Bid
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# Call
# ---
# Bid
# Bid
# ---
# Call
# Call
# Call
# Call
# Bid
# Bid
# ---
# Bid
# Bid
# Call
# Call
# Call
# Call
# ---
# Call
# Bid
# Bid
# ---
# Bid
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Bid
# ---
# Bid
# Bid
# Call
# Call
# ---
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# ---
# Call
# Call
# Bid
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# Call
# Bid
# Call
# Call
# Bid
# Call
# Call
# Bid
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# Bid
# ---
# ---
# Call
# Call
# Call
# ---
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Bid
# Call
# Call
# ---
# Call
# Bid
# ---
# ---
# Call
# Bid
# Call
# ---
# Call
# Bid
# ---
# Bid
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Bid
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# ---
# Call
# Bid
# Call
# ---
# Call
# Bid
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Bid
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# Bid
# ---
# Bid
# Bid
# Bid
# Call
# ---
# Bid
# Call
# ---
# Call
# ---
# Bid
# Bid
# ---
# Call
# ---
# ---
# ---
# Bid
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# Bid
# ---
# ---
# ---
# Bid
# ---
# Call
# ---
# Call
# Bid
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# Bid
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# ---
# Call
# ---
# ---
# Bid
# ---
# Call
# Bid
# Bid
# Bid
# Call
# ---
# Call
# Call
# ---
# Bid
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Bid
# Call
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# USD15.50
# USD31.00
# USD21.70
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# Bid
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# Bid
# Call
# USD14.50
# Call
# Bid
# ---
# Call
# Bid
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# Bid
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# Bid
# Bid
# Sold Out
# Bid
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Bid
# ---
# ---
# Call
# Call
# Call
# ---
# Bid
# Bid
# USD15.45
# Bid
# Call
# Call
# Bid
# ---
# Bid
# ---
# ---
# ---
# ---
# Bid
# Call
# Call
# ---
# Call
# ---
# Call
# Bid
# ---
# Call
# ---
# ---
# ---
# Bid
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# Bid
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Sold Out
# Call
# Bid
# Bid
# Bid
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# Bid
# Bid
# Call
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# USD11.55
# Bid
# Call
# Call
# Bid
# Bid
# Bid
# Call
# Call
# ---
# ---
# Call
# ---
# Call
# Call
# Bid
# Bid
# Call
# Call
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Bid
# Call
# Bid
# Call
# Call
# Call
# Bid
# Bid
# Bid
# Bid
# Sold Out
# Call
# Call
# Call
# Call
# Bid
# Call
# Bid
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# Bid
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Sold Out
# Bid
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# Bid
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Bid
# ---
# Call
# Bid
# ---
# Bid
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# Bid
# ---
# ---
# Call
# ---
# Bid
# ---
# ---
# ---
# Bid
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# Bid
# ---
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# ---
# ---
# ---
# Bid
# Bid
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# Bid
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# Bid
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# Bid
# ---
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Bid
# Bid
# ---
# Bid
# ---
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# Call
# Bid
# Call
# ---
# Call
# ---
# Call
# Bid
# Bid
# Call
# ---
# ---
# Bid
# Call
# Bid
# Bid
# Bid
# Call
# ---
# Call
# Call
# ---
# Call
# Call
# Bid
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# Call
# ---
# Bid
# Call
# Call
# Bid
# Call
# ---
# ---
# Bid
# Call
# ---
# Call
# Call
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# Call
# Bid
# ---
# Call
# ---
# ---
# Bid
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# USD75.00
# Call
# Bid
# Bid
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Bid
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# Call
# Call
# Bid
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# Call
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Bid
# Call
# Call
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Bid
# Bid
# Call
# Bid
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# Bid
# ---
# ---
# Call
# Bid
# ---
# Bid
# Bid
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# Bid
# Bid
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# Bid
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# Call
# Bid
# Call
# Call
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Bid
# ---
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# Sold Out
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# Bid
# Call
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Bid
# Bid
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Bid
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# Bid
# ---
# ---
# Bid
# Bid
# Call
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Bid
# ---
# Call
# ---
# ---
# Bid
# ---
# Call
# Bid
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# Bid
# ---
# Call
# ---
# Call
# Call
# ---
# ---
# Bid
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# Call
# ---
# USD12.00
# Call
# Call
# ---
# ---
# ---
# Call
# USD11.30
# Call
# ---
# Call
# Call
# ---
# Bid
# Call
# ---
# Bid
# Call
# USD10.00
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# USD11.20
# USD12.30
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# ---
# Call
# Bid
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Bid
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# Call
# Bid
# ---
# Call
# ---
# Bid
# Call
# ---
# Bid
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# Call
# ---
# Bid
# Call
# USD12.36
# Bid
# Call
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# USD11.50
# ---
# USD11.00
# ---
# Call
# Call
# USD13.10
# USD11.30
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# Call
# Bid
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Bid
# ---
# Call
# Call
# Bid
# ---
# ---
# Call
# Bid
# ---
# ---
# Call
# ---
# Bid
# Call
# ---
# Call
# Call
# ---
# ---
# Sold Out
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# Bid
# Bid
# ---
# ---
# ---
# ---
# Call
# ---
# Bid
# ---
# ---
# ---
# ---
# USD18.54
# Call
# ---
# Call
# Bid
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# Bid
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Bid
# Call
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# Bid
# Call
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Bid
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# Bid
# ---
# Bid
# Call
# ---
# Call
# Sold Out
# Call
# Call
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# Call
# Sold Out
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Bid
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# Bid
# Bid
# ---
# Call
# ---
# USD20.50
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# Bid
# Bid
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# Call
# Bid
# Bid
# Call
# ---
# ---
# Sold Out
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# Bid
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# Call
# ---
# Call
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Bid
# Bid
# ---
# ---
# Call
# ---
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Bid
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# Bid
# Call
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# Call
# Bid
# ---
# Bid
# ---
# Bid
# Call
# Call
# ---
# ---
# Call
# ---
# Call
# Call
# Bid
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# Call
# Call
# Call
# Bid
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Sold Out
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Bid
# Call
# ---
# Bid
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Bid
# ---
# ---
# Bid
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# Call
# Bid
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Bid
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# Bid
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# Call
# Call
# Bid
# Call
# Bid
# Bid
# ---
# ---
# Bid
# Call
# Bid
# Call
# ---
# ---
# Call
# Call
# Sold Out
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Bid
# Bid
# Call
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# Bid
# ---
# Bid
# Call
# ---
# Call
# ---
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# Bid
# Call
# ---
# Call
# ---
# Call
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# USD11.50
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# Bid
# Call
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# Call
# ---
# USD21.12
# ---
# ---
# USD54.28
# ---
# ---
# USD17.51
# ---
# Call
# ---
# ---
# USD16.80
# Bid
# Bid
# Call
# Call
# Bid
# Call
# Call
# ---
# USD22.66
# ---
# ---
# Call
# Call
# Call
# USD14.94
# ---
# Call
# USD29.36
# USD29.46
# ---
# USD14.50
# USD14.63
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Bid
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# Call
# Call
# Call
# Call
# ---
# ---
# ---
# Bid
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# Bid
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# Call
# Bid
# Bid
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# Bid
# ---
# ---
# ---
# ---
# Call
# Call
# Call
# ---
# Call
# Call
# Call
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# USD17.00
# ---
# ---
# ---
# Bid
# ---
# Call
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# Call
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Bid
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# Bid
# ---
# ---
# ---
# Bid
# Call
# Call
# ---
# ---
# ---
# ---
# Bid
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Bid
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# Call
# ---
# Call
# ---
# ---
# Bid
# Bid
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# Call
# ---
# ---
# ---
# ---
# ---
# USD14.80
# Call
# ---
# Bid
# ---
# USD15.00
# ---
# ---
# Call
# Call

# %%
########################################
# 📓 Repeat the check that the quantity numbers are valid numbers
######################################## 
# 1 - load data
qty = read_pickle("datasets/DRAM_OfferScraperOutput.pkl")['Qty']

# 2 - regular expression
regexp = "🍄🍄🍄🍄🍄"

# 3 - move through the list and try to find a match
for idx, i in enumerate(prices):

    mg = re.fullmatch(regexp, i, re.IGNORECASE)

    if (mg is None):
        print(i)
        qty[idx] = "INCORRECT FORMAT"

# %% [markdown]
# # Using groups
# <a id="groups"></a>
# Brackets are used to access specifc elements of a matched pattern. Brackets are evaluated in order of: external → internal and then by order of occurence.
#
# <img src="images_inkscape/groups.png" height="100">
#
# Brackets are also required to
# - Encapsulating `or` regular expressions e.g. `(Intel|Microsoft|AMD)`
# - Encapsulating expressions for repetitions e.g. `(\d\w)*` to match number-letter pattern of 1F2G3G
#
# <table class="table table-striped table-bordered table-hover table-condensed">
# <colgroup>
# <col  class="left">
# <col  class="left">
# </colgroup>
#
# <tbody>
#
# <tr>
# <td class="text-left"><code>"(&#x2026;)"</code></td>
# <td class="text-left">Create a group for the chosen regexp</td>
# <td class="text-left"></td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"(?:&#x2026;)"</code></td>
# <td class="text-left">Content is not assigned to a group for later access</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"(?!&#x2026;)"</code></td>
# <td class="text-left">Matches if &#x2026; doesn't match</td>
# </tr>
#
# </tbody>
# </table>

# %%
########################################
# 🍏 Creating groups to eliminate white spaces
########################################
# 1 - load data
example = ["1666MHz", "200 mHz", "speed = 300 khz"]

# 2 - regular expression to match:
# 2-4 digits, white space, khz or mhz
regexp = "(\d{2,4})(\s)?([km]hz)"

for i in example:
    # 3 - perform search
    mg = re.findall(regexp, i, re.IGNORECASE)[0]
    # 4 - eliminate white space during writing
    print(mg[0] + mg[2])
# Out:
# 1666MHz
# 200mHz
# 300khz

# %% [markdown]
# # Using advaced regular experssions
# <div id="content" class="container">
# <div class="row"><div class="col-md-9"><h1 class="title"></h1>
# <table class="table table-striped table-bordered table-hover table-condensed">
#
#
# <colgroup>
# <col  class="left">
#
# <col  class="left">
# </colgroup>
# <tbody>
# <tr>
# <td class="text-left"><code>"DDR[0-9]\b"</code></td>
# <td class="text-left">DDR3, DDR4</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"i\\. o\\. data"</code></td>
# <td class="text-left">i. o. data</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"so(?</code>\s)?dimm"=</td>
# <td class="text-left">so-dimm</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"class\s?\d+"</code></td>
# <td class="text-left">class10, class 6</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"\w+-\w+-\w+"</code></td>
# <td class="text-left">3-3-3, 66-200-21</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"\d+ pcs/pack"</code></td>
# <td class="text-left">2pcs/pack, 4pc/pack</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"i\d[-\s]\w+"</code></td>
# <td class="text-left">i7-21421</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"\w{0,2}1333"</code></td>
# <td class="text-left">PC1333</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"[0-9]{1,3}[MK]\sCache"</code></td>
# <td class="text-left">2M Cache, 20M Cache, 300MCache</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"[0-9]{1,2}x\s\w+</code></td>
# <td class="text-left">2x L3311, 12x L3123, 14x L3423</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"[0-9]+[Mm][Hh][Zz]"</code></td>
# <td class="text-left">800MHz, 12mhz, 30mhz</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"[0-9]{2,4}pins"</code></td>
# <td class="text-left">666pins, 77pins, 700pins</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"\w+\s[bB][iI][tT]"</code></td>
# <td class="text-left">64BIT, 128bit, 34bit</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"\bd+[GMK]b?/s"</code></td>
# <td class="text-left">100M/s, 200MB/s, 12Gb/s</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"\d+(\\.\d+)?(\s)?[gmk]bps"</code></td>
# <td class="text-left">8.0Gbps, 20 kbps</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"(\w{4,20})\s(I{2,4})"</code></td>
# <td class="text-left">Pentinum II</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"E[0-9]-\w{4,6}"</code></td>
# <td class="text-left">E2-12421</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"\d\\.\dv"</code></td>
# <td class="text-left">2.2v</td>
# </tr>
#
#
# <tr>
# <td class="text-left"><code>"\w+\sEd(ition|\\.)"</code></td>
# <td class="text-left">Black edition</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"\d+(\\.\d+)?\s?(\"|\s?inch)"</code></td>
# <td class="text-left">2.5 inch</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"SATA(-|\s)?II{2,4}"</code></td>
# <td class="text-left">sata III</td>
# </tr>
#
# </tbody>
# </table>
# </div><div class="col-md-3"></div></div></div>
#
# ***
# In addition to the table, this is a further list of common elements
# ```python
# common regexp = "heat(?=\s)?shield|hyper|EEC|Reg|Chip(s)|BGA|CSP|quad",
#             "mobile|b[op]x|giant|tin|gold|lead|dual|die|tray",
#             "legacy|sodimm|(s)?TSOP|stack(ed)?|layer|SDRAM|cache",
#             "CPU|coated|Orig(inal)?|FBGA|for",
#             "scalable|bridge|north|south|type|core|duo|dual"```

# %%
########################################
# 📓 1 -Use the above regexp and slot them into the "regexp = [....]" variable below, to extract all meaningful data
#    2 - try it for different description files
######################################## 
# 1 - load data
#description = read_pickle("datasets/SSD_OfferScraperOutput.pkl")['Description']
#description = read_pickle("datasets/Module_OfferScraperOutput.pkl")['Description']
#description = read_pickle("datasets/FlashCard_OfferScraperOutput.pkl")['Description']
description = read_pickle("datasets/DRAM_OfferScraperOutput.pkl")['Description']

# 2 - regular expression, given as a list
regexp = ["[0-9]+[Mm][Hh][Zz]", "\bd+[GMK]b?/s"]

# 3 - regular expression are joined with an OR
regexp = "(" + "|".join(regexp) + ")"

# 4 - move through the description list
description_extracted = []
for idx, i in enumerate(description):

    mg = re.findall(regexp, i, re.IGNORECASE)
    
    # 4 - add what was extracted
    if (len(mg) != 0):
        description_extracted.append(mg)
        print("Extracted\t\t", mg)
    else:
        # 5 - flag what is still to be extracted
        print("✘ Nothing found with\t", i)
# Out:
# ✘ Nothing found with	 GDDR5 256Mx32 1.35v (8Gb)
# ✘ Nothing found with	 GDDR5 256Mx32-60
# ✘ Nothing found with	 GDDR5 256Kx32-03
# ✘ Nothing found with	 GDDR5 256Kx32-28
# ✘ Nothing found with	 GDDR5 256Mx32-70
# ✘ Nothing found with	 GDDR5 256Mx32-70
# ✘ Nothing found with	 GDDR5 256Kx32-24
# ✘ Nothing found with	 GDDR5 256Kx32-25
# ✘ Nothing found with	 GDDR5 256Mx32 1.35v (8Gb)
# ✘ Nothing found with	 GDDR5 256Mx32-80
# ✘ Nothing found with	 GDDR5 256Mx32
# ✘ Nothing found with	 GDDR5 256Mx32-80
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32 8.0Gbps
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 128Mx32
# ✘ Nothing found with	 GDDR5 64Mx32-60
# ✘ Nothing found with	 GDDR5 64Mx32-6A
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 64Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# ✘ Nothing found with	 GDDR5 32Mx32
# Extracted		 ['1200Mhz']
# Extracted		 ['1200Mhz']
# ✘ Nothing found with	 GDDR3 64Mx16-12C 1600
# ✘ Nothing found with	 GDDR3 512Mx16-11C
# ✘ Nothing found with	 GDDR3 256Mx16-11
# ✘ Nothing found with	 GDDR3 256Mx16-11
# ✘ Nothing found with	 GDDR3 256Mx16-11
# ✘ Nothing found with	 GDDR3 256Mx16 1GHz
# ✘ Nothing found with	 GDDR3 256Mx16 1GHz
# ✘ Nothing found with	 GDDR3 256Mx16 1GHz
# ✘ Nothing found with	 GDDR3 256Mx16 1.0GHz
# ✘ Nothing found with	 GDDR3 256Mx16-1A
# ✘ Nothing found with	 GDDR3 256Mx16-1A
# ✘ Nothing found with	 GDDR3 256Mx16-091G
# ✘ Nothing found with	 GDDR3 256Mx16
# ✘ Nothing found with	 GDDR3 256Mx16
# ✘ Nothing found with	 GDDR3 256Mx8-15
# ✘ Nothing found with	 GDDR3 256Mx8 1.5v
# ✘ Nothing found with	 GDDR3 128Mx16-12
# ✘ Nothing found with	 GDDR3 128Mx16-12
# ✘ Nothing found with	 GDDR3 128Mx16-12
# ✘ Nothing found with	 GDDR3 128Mx16-11
# ✘ Nothing found with	 GDDR3 128Mx16-11
# ✘ Nothing found with	 GDDR3 128Mx16-11
# ✘ Nothing found with	 GDDR3 128Mx16-11
# ✘ Nothing found with	 GDDR3 128Mx16 1GHz
# ✘ Nothing found with	 GDDR3 128Mx16 1GHz
# ✘ Nothing found with	 GDDR3 128Mx16-1A
# ✘ Nothing found with	 GDDR3 128Mx16-1A
# ✘ Nothing found with	 GDDR3 128Mx16 PC1866
# ✘ Nothing found with	 GDDR3 128Mx16 PC1866
# Extracted		 ['900MHz']
# ✘ Nothing found with	 GDDR3 128Mx16-12
# ✘ Nothing found with	 GDDR3 128Mx16-12
# ✘ Nothing found with	 GDDR3 128Mx16-12
# ✘ Nothing found with	 GDDR3 128Mx16-11
# ✘ Nothing found with	 GDDR3 128Mx16
# ✘ Nothing found with	 GDDR3 128Mx8-15
# ✘ Nothing found with	 GDDR3 64Mx32 1GHz
# ✘ Nothing found with	 GDDR3 64Mx16-12C 1600
# ✘ Nothing found with	 GDDR3 64Mx16-12C 1600
# ✘ Nothing found with	 GDDR3 64Mx16-12C 1600
# ✘ Nothing found with	 GDDR3 64Mx16-12
# ✘ Nothing found with	 DDR3 64Mx16 PC1066
# ✘ Nothing found with	 DDR3 64Mx16 PC1066
# ✘ Nothing found with	 DDR3 64Mx16 PC1066 FBGA
# ✘ Nothing found with	 DDR3 64Mx16 PC1066
# ✘ Nothing found with	 DDR3 64Mx16 PC1066
# ✘ Nothing found with	 GDDR3 64Mx32
# ✘ Nothing found with	 GDDR3 64Mx16-12
# ✘ Nothing found with	 GDDR3 64Mx16-12
# ✘ Nothing found with	 GDDR3 64Mx16-12
# ✘ Nothing found with	 GDDR3 64Mx16-11
# ✘ Nothing found with	 GDDR3 64Mx16-11
# ✘ Nothing found with	 GDDR3 64Mx16-11
# ✘ Nothing found with	 GDDR3 64Mx16-11
# ✘ Nothing found with	 GDDR3 64Mx16 1.5, halogen free
# ✘ Nothing found with	 GDDR3 32Mx32 1.4 lead free, halogen free
# Extracted		 ['700MHz']
# ✘ Nothing found with	 GDDR3 32Mx32 1.4, halogen free
# ✘ Nothing found with	 GDDR3 32Mx32 1.2 lead free, halogen free
# ✘ Nothing found with	 GDDR3 32Mx32 1.4
# ✘ Nothing found with	 GDDR3 32Mx32 1.1 lead free, halogen free
# ✘ Nothing found with	 GDDR3 32Mx32 1.0 lead free, halogen free
# ✘ Nothing found with	 GDDR3 32Mx32 1.0, halogen free
# ✘ Nothing found with	 GDDR3 32Mx32 1.0 lead free, halogen free
# ✘ Nothing found with	 GDDR3 32Mx32
# ✘ Nothing found with	 GDDR3 32Mx32
# ✘ Nothing found with	 GDDR3 32Mx32
# ✘ Nothing found with	 GDDR3 32Mx32
# ✘ Nothing found with	 GDDR3 32Mx32
# ✘ Nothing found with	 GDDR3 32Mx32
# ✘ Nothing found with	 GDDR3 32Mx32
# ✘ Nothing found with	 GDDR3 32Mx32
# ✘ Nothing found with	 GDDR3 32Mx32
# ✘ Nothing found with	 GDDR3 32Mx32 halogen free
# Extracted		 ['700MHz']
# Extracted		 ['350MHz']
# Extracted		 ['350MHz']
# Extracted		 ['350MHz']
# ✘ Nothing found with	 GDDR3 32Mx16-16
# Extracted		 ['1200Mhz']
# ✘ Nothing found with	 GDDR3 16Mx32 1GHz
# ✘ Nothing found with	 GDDR3 16Mx32 1200MGHz
# Extracted		 ['1000MHz']
# ✘ Nothing found with	 GDDR3 16Mx32
# Extracted		 ['1000Mhz']
# Extracted		 ['1000Mhz']
# Extracted		 ['1000Mhz']
# Extracted		 ['900MHz']
# ✘ Nothing found with	 GDDR3 16Mx32 900 MHz
# Extracted		 ['800Mhz']
# Extracted		 ['800Mhz']
# Extracted		 ['800Mhz']
# Extracted		 ['800Mhz']
# Extracted		 ['800Mhz']
# Extracted		 ['800Mhz']
# Extracted		 ['800Mhz']
# Extracted		 ['800Mhz']
# Extracted		 ['700Mhz']
# Extracted		 ['700MHz']
# Extracted		 ['700MHz']
# Extracted		 ['700MHz']
# Extracted		 ['700Mhz']
# Extracted		 ['700MHz']
# Extracted		 ['900MHZ']
# ✘ Nothing found with	 GDDR3 16Mx32-10 TFBGA 136
# ✘ Nothing found with	 GDDR3 16Mx32-10 TFBGA 136
# Extracted		 ['700MHz']
# Extracted		 ['700MHz']
# Extracted		 ['700MHz']
# Extracted		 ['700MHz']
# Extracted		 ['700MHz']
# Extracted		 ['700MHz']
# ✘ Nothing found with	 GDDR3 16Mx32-0.7
# ✘ Nothing found with	 GDDR3 16Mx32
# ✘ Nothing found with	 GDDR3 16Mx32
# ✘ Nothing found with	 GDDR3 16Mx32
# ✘ Nothing found with	 GDDR3 16Mx32
# ✘ Nothing found with	 GDDR3 16Mx32
# ✘ Nothing found with	 GDDR3 16Mx32
# ✘ Nothing found with	 GDDR3 16Mx32
# ✘ Nothing found with	 GDDR3 16Mx32
# ✘ Nothing found with	 GDDR3 16Mx32
# Extracted		 ['1000MHz']
# Extracted		 ['1000MHz']
# Extracted		 ['900Mhz']
# Extracted		 ['800MHz']
# Extracted		 ['700MHz']
# Extracted		 ['700MHz']
# Extracted		 ['700MHz']
# Extracted		 ['700MHz']
# Extracted		 ['700MHz']
# Extracted		 ['700Mhz']
# Extracted		 ['700Mhz']
# Extracted		 ['700MHz']
# Extracted		 ['700Mhz']
# Extracted		 ['700Mhz']
# Extracted		 ['700Mhz']
# Extracted		 ['700Mhz']
# Extracted		 ['700Mhz']
# Extracted		 ['700Mhz']
# Extracted		 ['600Mhz']
# Extracted		 ['500MHz']
# Extracted		 ['500MHz']
# Extracted		 ['500Mhz']
# Extracted		 ['500Mhz']
# Extracted		 ['500Mhz']
# Extracted		 ['500Mhz']
# Extracted		 ['500Mhz']
# ✘ Nothing found with	 GDDR3 8Mx32 FBGA 1.8v
# ✘ Nothing found with	 GDDR3 8Mx32 FBGA 1.8v
# ✘ Nothing found with	 GDDR3 8Mx32 FBGA 1.8v
# ✘ Nothing found with	 GDDR3 8Mx32 FBGA 1.8v
# ✘ Nothing found with	 GDDR3 8Mx32 FBGA 1.8v
# ✘ Nothing found with	 GDDR3 8Mx32 FBGA
# ✘ Nothing found with	 GDDR3 8Mx32 FBGA144
# Extracted		 ['500MHz']
# Extracted		 ['400MHz']
# Extracted		 ['400MHz']
# Extracted		 ['400MHz']
# ✘ Nothing found with	 GDDR2 64Mx16-25
# ✘ Nothing found with	 GDDR2 64Mx16-20
# ✘ Nothing found with	 GDDR2 64Mx16-16
# ✘ Nothing found with	 GDDR2 64Mx16-2.5
# ✘ Nothing found with	 GDDR2 64Mx16-2.0
# ✘ Nothing found with	 GDDR2 64Mx16-2.0
# ✘ Nothing found with	 GDDR2 64Mx16-2.0
# ✘ Nothing found with	 GDDR2 64Mx16
# Extracted		 ['500MHz']
# Extracted		 ['500MHz']
# Extracted		 ['500MHz']
# Extracted		 ['400MHz']
# Extracted		 ['400MHz']
# Extracted		 ['400MHz']
# Extracted		 ['400MHz']
# Extracted		 ['400MHz']
# ✘ Nothing found with	 GDDR2 32Mx16 PC400
# Extracted		 ['350MHz']
# ✘ Nothing found with	 GDDR2 32Mx16-25
# ✘ Nothing found with	 GDDR2 32Mx16-20C
# ✘ Nothing found with	 GDDR2 32Mx16-20L
# ✘ Nothing found with	 GDDR2 32Mx16-20L
# ✘ Nothing found with	 GDDR2 32Mx16-20
# ✘ Nothing found with	 GDDR2 32Mx16-20
# ✘ Nothing found with	 GDDR2 32Mx16-20 Lead Free, halogen free
# ✘ Nothing found with	 GDDR2 32Mx16-2.8
# ✘ Nothing found with	 GDDR2 32Mx16-2.8
# ✘ Nothing found with	 GDDR2 32Mx16-2.5
# ✘ Nothing found with	 GDDR2 32Mx16-2.5 Lead Free, halogen free
# ✘ Nothing found with	 GDDR2 32Mx16
# ✘ Nothing found with	 GDDR2 16Mx16 PC667 Pb free
# ✘ Nothing found with	 GDDR2 16Mx16 PC533 Pb free
# ✘ Nothing found with	 GDDR2 16Mx16 PC533
# ✘ Nothing found with	 GDDR2 16Mx16 PC533
# ✘ Nothing found with	 GDDR2 16Mx16 PC533
# ✘ Nothing found with	 GDDR2 16Mx16-33
# ✘ Nothing found with	 GDDR2 16Mx16-28
# ✘ Nothing found with	 GDDR2 16Mx16-25
# ✘ Nothing found with	 GDDR2 16Mx16-25
# ✘ Nothing found with	 GDDR2 16Mx16-25
# ✘ Nothing found with	 GDDR2 16Mx16-20
# ✘ Nothing found with	 GDDR2 16Mx16-2L
# ✘ Nothing found with	 GDDR2 16Mx16-2.8 Lead Free
# ✘ Nothing found with	 GDDR2 16Mx16-2.8 Lead Free
# ✘ Nothing found with	 GDDR2 16Mx16-2.5 Lead Free
# ✘ Nothing found with	 GDDR2 16Mx16-2.5 Lead Free
# ✘ Nothing found with	 GDDR2 16Mx16-2.0 Lead Free
# ✘ Nothing found with	 GDDR2 16Mx16 Lead Free
# ✘ Nothing found with	 GDDR2 16Mx16 Lead Free
# ✘ Nothing found with	 GDDR2 16Mx16
# ✘ Nothing found with	 GDDR2 16Mx16
# ✘ Nothing found with	 GDDR2 16Mx16
# ✘ Nothing found with	 GDDR2 16Mx16
# ✘ Nothing found with	 GDDR2 16Mx16
# ✘ Nothing found with	 GDDR2 16Mx16
# ✘ Nothing found with	 GDDR2 16Mx16
# ✘ Nothing found with	 GDDR2 16Mx16
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# ✘ Nothing found with	 GDDR 32Mx16
# ✘ Nothing found with	 GDDR 32Mx16
# ✘ Nothing found with	 GDDR 16Mx16 PC500
# Extracted		 ['333MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300Mhz']
# Extracted		 ['300Mhz']
# Extracted		 ['275MHz']
# Extracted		 ['275Mhz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250Mhz']
# Extracted		 ['250Mhz']
# Extracted		 ['250Mhz']
# Extracted		 ['250Mhz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200Mhz']
# Extracted		 ['200Mhz']
# Extracted		 ['200Mhz']
# Extracted		 ['200Mhz']
# Extracted		 ['200Mhz']
# Extracted		 ['200Mhz']
# Extracted		 ['200Mhz']
# Extracted		 ['200Mhz']
# Extracted		 ['200Mhz']
# Extracted		 ['200Mhz']
# Extracted		 ['200Mhz']
# Extracted		 ['166MHz']
# Extracted		 ['166MHz']
# Extracted		 ['166MHz']
# Extracted		 ['166Mhz']
# Extracted		 ['166Mhz']
# Extracted		 ['166Mhz']
# ✘ Nothing found with	 GDDR 16Mx16
# ✘ Nothing found with	 GDDR 16Mx16
# ✘ Nothing found with	 GDDR 16Mx16
# ✘ Nothing found with	 GDDR 16Mx16 Pb free
# ✘ Nothing found with	 GDDR 16Mx16 TSOP Pb Free
# ✘ Nothing found with	 GDDR 16Mx16 TSOP Pb Free
# Extracted		 ['400Mhz']
# Extracted		 ['350Mhz']
# Extracted		 ['300MHz']
# Extracted		 ['300Mhz']
# Extracted		 ['300Mhz']
# Extracted		 ['300Mhz']
# Extracted		 ['300MHz']
# Extracted		 ['300Mhz']
# Extracted		 ['275MHz']
# Extracted		 ['275Mhz']
# Extracted		 ['275MHz']
# ✘ Nothing found with	 GDDR 8Mx32-33
# ✘ Nothing found with	 GDDR 8Mx32-33
# ✘ Nothing found with	 GDDR 8Mx32-33
# ✘ Nothing found with	 GDDR 8MX32-33
# ✘ Nothing found with	 GDDR 8Mx32-33
# ✘ Nothing found with	 GDDR 8MX32-33
# ✘ Nothing found with	 GDDR 8Mx32-33 FBGA
# ✘ Nothing found with	 GDDR 8Mx32-28
# ✘ Nothing found with	 GDDR 8Mx32-28
# ✘ Nothing found with	 GDDR 8MX32-28
# ✘ Nothing found with	 GDDR 8MX32-28
# ✘ Nothing found with	 GDDR 8Mx32-28 Pb Free
# ✘ Nothing found with	 GDDR 8Mx32-28
# ✘ Nothing found with	 GDDR 8Mx32-28
# ✘ Nothing found with	 GDDR 8Mx32-25 Pb Free
# ✘ Nothing found with	 GDDR 8Mx32-4
# ✘ Nothing found with	 GDDR 8Mx32-2A FBGA
# ✘ Nothing found with	 GDDR 8Mx32
# ✘ Nothing found with	 GDDR 8Mx32
# ✘ Nothing found with	 GDDR 8Mx32
# ✘ Nothing found with	 GDDR 8Mx32
# ✘ Nothing found with	 GDDR 8Mx32 FBGA
# ✘ Nothing found with	 GDDR 8Mx32 FBGA
# ✘ Nothing found with	 GDDR 8Mx32 FBGA
# ✘ Nothing found with	 GDDR 8Mx32 FBGA Pb Free
# ✘ Nothing found with	 GDDR 8Mx32 FBGA Pb Free
# Extracted		 ['350MHz']
# ✘ Nothing found with	 GDDR 8Mx16-5 TSOP Pb Free
# ✘ Nothing found with	 GDDR 8Mx16/333
# ✘ Nothing found with	 GDDR 8Mx16/333
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# ✘ Nothing found with	 GDDR 8Mx16
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['166MHz']
# Extracted		 ['166MHz']
# Extracted		 ['166MHz']
# Extracted		 ['166MHz']
# Extracted		 ['166MHz']
# Extracted		 ['166MHz']
# Extracted		 ['166MHz']
# ✘ Nothing found with	 GDDR 8Mx16-5 TSOP Pb Free
# ✘ Nothing found with	 GDDR 8Mx16-5 TSOP Pb Free
# ✘ Nothing found with	 GDDR 8Mx16-4
# ✘ Nothing found with	 GDDR 8Mx16-3.6 TSOP Pb Free
# ✘ Nothing found with	 GDDR 8Mx16
# ✘ Nothing found with	 GDDR 8Mx16
# ✘ Nothing found with	 GDDR 8Mx16
# Extracted		 ['500MHz']
# Extracted		 ['500MHz']
# Extracted		 ['450MHz']
# Extracted		 ['450MHz']
# Extracted		 ['400MHz']
# Extracted		 ['400MHz']
# ✘ Nothing found with	 GDDR 4Mx32
# Extracted		 ['400MHz']
# Extracted		 ['350MHz']
# Extracted		 ['400MHz']
# Extracted		 ['350MHz']
# Extracted		 ['350MHz']
# Extracted		 ['350MHz']
# Extracted		 ['350MHz']
# Extracted		 ['350MHz']
# Extracted		 ['350MHz']
# Extracted		 ['350MHz']
# Extracted		 ['350MHz']
# Extracted		 ['350MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['275MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# ✘ Nothing found with	 GDDR 4MX32-4.5 222 T-FBGA
# ✘ Nothing found with	 GDDR 4MX32 LP 222
# Extracted		 ['222MHz']
# Extracted		 ['222MHz']
# Extracted		 ['222MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# ✘ Nothing found with	 GDDR 4Mx32 200 MHz TQFP
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['183MHz']
# ✘ Nothing found with	 GDDR 4Mx32-36
# ✘ Nothing found with	 GDDR 4MX32-5
# ✘ Nothing found with	 GDDR 4Mx32-5.0, lead free, halogen free
# ✘ Nothing found with	 GDDR 4MX32-3.3
# ✘ Nothing found with	 GDDR 4MX32-3.0
# ✘ Nothing found with	 GDDR 4MX32
# ✘ Nothing found with	 GDDR 4MX32
# ✘ Nothing found with	 GDDR 4Mx32
# ✘ Nothing found with	 GDDR 4Mx32 FBGA
# ✘ Nothing found with	 GDDR 4Mx32 FBGA
# ✘ Nothing found with	 GDDR 4Mx32
# ✘ Nothing found with	 GDDR 4Mx32
# ✘ Nothing found with	 GDDR 4Mx32
# ✘ Nothing found with	 GDDR 4Mx32 FBGA
# ✘ Nothing found with	 GDDR 4Mx32 FBGA
# ✘ Nothing found with	 GDDR 4Mx32
# ✘ Nothing found with	 4M*32 DDR
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['183MHz']
# Extracted		 ['183MHz']
# Extracted		 ['166MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['250MHz']
# Extracted		 ['300MHz']
# Extracted		 ['300MHz']
# Extracted		 ['250MHz']
# Extracted		 ['222MHz']
# Extracted		 ['222MHz']
# Extracted		 ['222MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['200MHz']
# Extracted		 ['183MHz']
# Extracted		 ['166MHz']
# Extracted		 ['166MHz']
# Extracted		 ['166MHz']
# Extracted		 ['166MHz']
# Extracted		 ['1600MHz']
# ✘ Nothing found with	 8Gb LPDDR
# ✘ Nothing found with	 LPDDR3 24G (768Mx32) FBGA
# ✘ Nothing found with	 16GB LPDDR4
# ✘ Nothing found with	 Mobile LPDDR4 16GB x32
# ✘ Nothing found with	 Mobile DDR4 256Mx32 Low Power ( LPDDR4 )
# ✘ Nothing found with	 Mobile DDR4 256Mx64 Low Power ( LPDDR4 )
# ✘ Nothing found with	 Mobile DDR4 256Mx32 Low Power ( LPDDR4 )
# ✘ Nothing found with	 16GB LPDDR4
# ✘ Nothing found with	 Mobile DDR4 384Mx64 Low Power ( LPDDR4 )
# ✘ Nothing found with	 24GB LPDDR4
# ✘ Nothing found with	 Mobile DDR4 256Mx32 Low Power ( LPDDR4 )
# ✘ Nothing found with	 16GB LPDDR4
# ✘ Nothing found with	 24GB LPDDR4
# ✘ Nothing found with	 16GB LPDDR4
# ✘ Nothing found with	 Mobile DDR4 384Mx64 Low Power ( LPDDR4 )
# ✘ Nothing found with	 8Gb LPDDR
# ✘ Nothing found with	 Mobile DDR4 384Mx32 Low Power ( LPDDR4 )
# ✘ Nothing found with	 Mobile DDR4 384Mx64 Low Power ( LPDDR4 )
# ✘ Nothing found with	 Mobile DDR4 512Mx32 Low Power ( LPDDR4 )
# ✘ Nothing found with	 32GB LPDDR4
# ✘ Nothing found with	 24GB LPDDR4
# ✘ Nothing found with	 32GB LPDDR4
# ✘ Nothing found with	 24GB LPDDR4
# ✘ Nothing found with	 Mobile DDR4 512Mx64 Low Power ( LPDDR4 )
# ✘ Nothing found with	 32GB LPDDR4
# ✘ Nothing found with	 32GB LPDDR4
# ✘ Nothing found with	 Mobile DDR4 512Mx64 Low Power ( LPDDR4 )
# ✘ Nothing found with	 32GB LPDDR4
# ✘ Nothing found with	 24GB LPDDR4
# ✘ Nothing found with	 Mobile DDR4 512Mx32 Low Power ( LPDDR4 )
# ✘ Nothing found with	 32GB LPDDR4
# ✘ Nothing found with	 Mobile LPDDR4 3GB
# Extracted		 ['1600MHz']
# ✘ Nothing found with	 Mobile LPDDR4 4GB
# ✘ Nothing found with	 Mobile LPDDR4 3GB
# ✘ Nothing found with	 Mobile LPDDR4 8GB
# ✘ Nothing found with	 Mobile LPDDR4 4GB
# ✘ Nothing found with	 Mobile LPDDR4 16GB 512Mx32
# ✘ Nothing found with	 Mobile LPDDR4 8GB
# ✘ Nothing found with	 Mobile LPDDR4 4GB
# ✘ Nothing found with	 Mobile LPDDR4 4GB
# ✘ Nothing found with	 Mobile LPDDR4 32GB x32 bit
# ✘ Nothing found with	 Mobile LPDDR4 4GB
# ✘ Nothing found with	 Mobile DDR4 256Mx32 Low Power ( LPDDR4 )
# ✘ Nothing found with	 Mobile LPDDR4 4GB
# ✘ Nothing found with	 16GB LPDDR4
# ✘ Nothing found with	 Mobile LPDDR4 1Gx32 Low Power (LPDDR4)
# ✘ Nothing found with	 Mobile LPDDR4 512Mx32 Low Power (LPDDR4)
# ✘ Nothing found with	 16Gb LPDDR4
# ✘ Nothing found with	 48Gb LPDDR4
# ✘ Nothing found with	 Mobile LPDDR4 16Gb 512Mx32
# ✘ Nothing found with	 16Gb LPDDR4
# ✘ Nothing found with	 16Gb LPDDR4
# Extracted		 ['3200MHz']
# ✘ Nothing found with	 2GB LPDDR3
# ✘ Nothing found with	 Mobile LPDDR3 24GB 192Mx32 PC1866 256Ball
# Extracted		 ['800Mhz']
# ✘ Nothing found with	 LPDDR3 128Mx64 PC1600 (8Gb)
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 Mobile LPDDR3 24GB 192Mx32 PC1866
# ✘ Nothing found with	 LPDDR3 24Gb
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 Mobile LPDDR3 24GB 192Mx32 PC1866
# ✘ Nothing found with	 16GB LPDDR3
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 16GB LPDDR3
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 Mobile LPDDR3 16Gb 256Mx32 PC1866
# ✘ Nothing found with	 16GB LPDDR3
# ✘ Nothing found with	 16GB LPDDR3
# Extracted		 ['800MHz']
# ✘ Nothing found with	 16GB LPDDR3
# ✘ Nothing found with	 16GB LPDDR3
# ✘ Nothing found with	 LPDDR3 16Gb 512Mx32 PC1067
# ✘ Nothing found with	 16GB LPDDR3
# ✘ Nothing found with	 16GB LPDDR3
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 LPDDR3 32Gb
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 LPDDR3 8Gb
# ✘ Nothing found with	 LPDDR3 16Gbit
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 8GB LPDDR3
# ✘ Nothing found with	 8GB LPDDR3
# ✘ Nothing found with	 LPDDR3 8Gb
# ✘ Nothing found with	 LPDDR3 8Gb
# ✘ Nothing found with	 8GB LPDDR3
# ✘ Nothing found with	 LPDDR3 8Gb
# ✘ Nothing found with	 LPDDR3 8Gb
# ✘ Nothing found with	 LPDDR3 8Gb
# ✘ Nothing found with	 8GB LPDDR3 128Mx32
# ✘ Nothing found with	 8GB LPDDR3
# ✘ Nothing found with	 8GB LPDDR3
# ✘ Nothing found with	 LPDDR3 128Mx32 FBGA
# ✘ Nothing found with	 LPDDR3 128Mx32
# ✘ Nothing found with	 LPDDR3 8Gb
# ✘ Nothing found with	 LPDDR3 8Gb
# ✘ Nothing found with	 LPDDR3 8Gb
# ✘ Nothing found with	 LPDDR3 8G 256MX32 FBGA DDP
# ✘ Nothing found with	 LDDR3 128Mx32
# ✘ Nothing found with	 8GB LPDDR3
# ✘ Nothing found with	 LPDDR3 2G
# ✘ Nothing found with	 LPDDR3 8Gb
# ✘ Nothing found with	 LPDDR3 256Mx32 PC1866
# ✘ Nothing found with	 LPDDR3 512Mx32 PC1866
# ✘ Nothing found with	 LPDDR3 1Gx32 PC1866
# ✘ Nothing found with	 LPDDR3 512Mx32 PC1866
# ✘ Nothing found with	 LPDDR3 16Gb 256Mx64 PC1866
# ✘ Nothing found with	 LPDDR3 16Gb (128Mx32)
# ✘ Nothing found with	 LPDDR3 16Gb (128Mx32)
# ✘ Nothing found with	 LPDDR3 8Gb 256M x32 PC1866
# ✘ Nothing found with	 LPDDR3 8G 256Mx32 FBGA
# ✘ Nothing found with	 LPDDR3 8Gb 256M x32 PC1866
# ✘ Nothing found with	 LPDDR3 16G
# ✘ Nothing found with	 LPDDR3 32Gb 256x64 FBGA
# ✘ Nothing found with	 LPDDR3 16G
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 LPDDR3 8Gb 256M x32 1.2v
# ✘ Nothing found with	 8GB LPDDR3
# ✘ Nothing found with	 LPDDR3 128Mx64 PC800 (8Gb)
# ✘ Nothing found with	 Mobile LPDDR3 8Gb 256Mx32
# ✘ Nothing found with	 LPDDR3 32Gb
# ✘ Nothing found with	 8GB LPDDR3
# ✘ Nothing found with	 Mobile LPDDR3 8Gb 256Mx32
# ✘ Nothing found with	 LPDDR3 4G 64Mx32 178Ball FBGA
# ✘ Nothing found with	 LPDDR3 8Gb 256Mx32
# ✘ Nothing found with	 LPDDR3 8Gb 256Mx32
# Extracted		 ['2166MHz']
# ✘ Nothing found with	 LPDDR3 16GB
# ✘ Nothing found with	 LPDDR3 32Gb 1600
# ✘ Nothing found with	 LPDDR3 32Gb
# ✘ Nothing found with	 LPDDR3 32Gb
# ✘ Nothing found with	 LPDDR3 32Gb
# ✘ Nothing found with	 LPDDR3 16Gb (x32)
# ✘ Nothing found with	 LPDDR3 32G FBGA
# ✘ Nothing found with	 Mobile 4Gbit DDR2 (LPDDR2)
# ✘ Nothing found with	 Mobile DDR2 64Mx32 (LPDDR2)
# ✘ Nothing found with	 Mobile 4Gbit DDR2 (LPDDR2)
# ✘ Nothing found with	 Mobile DDR2 64Mx32 (LPDDR2)
# ✘ Nothing found with	 Mobile DDR2 (LPDDR2)
# ✘ Nothing found with	 Mobile DDR2 64Mx32 (LPDDR2)
# ✘ Nothing found with	 Mobile DDR2 64Mx32 (LPDDR2)
# ✘ Nothing found with	 Mobile DDR2 (LPDDR2)
# ✘ Nothing found with	 Mobile DDR2 (LPDDR2)
# ✘ Nothing found with	 Mobile DDR2 (LPDDR2)
# ✘ Nothing found with	 Mobile DDR2 (LPDDR2)
# ✘ Nothing found with	 Mobile DDR2 512Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 LPDDR2 128Mx32
# Extracted		 ['333MHz']
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 2Gb LPDDR2-S4
# Extracted		 ['400MHz']
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# Extracted		 ['400MHz']
# ✘ Nothing found with	 2Gb LPDDR2-S4
# ✘ Nothing found with	 8Gb LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2 16Gb 220 Ball FBGA
# ✘ Nothing found with	 8Gb LPDDR2
# ✘ Nothing found with	 8G LPDDR2
# ✘ Nothing found with	 LPDDR2 128Mx32 PC533
# ✘ Nothing found with	 8Gb LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2 128Mx32
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 8Gb LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2 128Mx16 PC1066
# ✘ Nothing found with	 8G LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2 128Mx32 PC400
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2 8Gb PC1066 pop216 2CH
# ✘ Nothing found with	 8Gb LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2 4G 128Mx32 PC400
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 2G LPDDR2
# ✘ Nothing found with	 4G LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2 128Mx32 PC800
# ✘ Nothing found with	 3x4Gb LPDDR2 216b PoP 35nm Q-die CS
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 Mobile DDR2 - LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2 4G 32Mx32 PC400
# ✘ Nothing found with	 Mobile LPDDR3 16GB 256Mx32 PC1866
# ✘ Nothing found with	 LPDDR2 4G 32Mx32 PC533
# ✘ Nothing found with	 LPDDR2 8G
# ✘ Nothing found with	 LPDDR2 32Mx16 PC400
# ✘ Nothing found with	 16G
# ✘ Nothing found with	 LPDDR2 8G
# ✘ Nothing found with	 LPDDR3 32G POP
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 512Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 8G LPDDR2
# ✘ Nothing found with	 Mobile DDR2 128Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 E512
# ✘ Nothing found with	 Mobile DDR2 128Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 4G LPDDR2
# ✘ Nothing found with	 Mobile DDR2 128Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 512Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 128Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 512Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 16Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 8G LPDDR2 216b
# ✘ Nothing found with	 Mobile DDR2 128Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 512Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 512Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 512Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 128Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 128Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 128Mx32
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 128Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 Mobile DDR2 512Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 16Gb LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 3X256MB LPDDR2 IN 240B POP
# ✘ Nothing found with	 3X256MB LPDDR2 IN 240B POP
# ✘ Nothing found with	 POPDDRONLY 2G
# ✘ Nothing found with	 POPDDRONLY 2G
# ✘ Nothing found with	 8GB LPDDR2 PoP 4x2Gb Dual Channel
# ✘ Nothing found with	 LPDDR3 16GB
# ✘ Nothing found with	 LPDDR 2G
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 LPDDR3
# ✘ Nothing found with	 Mobile DDR2 256Mx32 Low Power ( LPDDR2 )
# ✘ Nothing found with	 LPDDR3 16Gb (x32)
# ✘ Nothing found with	 LPDDR3 32Gb
# ✘ Nothing found with	 LPDDR3 128Mx32
# ✘ Nothing found with	 LPDDR3 16Gb (x32)
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 LPDDR3 16Gb
# ✘ Nothing found with	 8GB LPDDR2 PoP 4x2Gb Dual Channel
# ✘ Nothing found with	 Mobile LPDDR3 16GB 256Mx32 PC1866
# ✘ Nothing found with	 LPDDR3 32Gb
# ✘ Nothing found with	 LPDDR3 32Gb
# ✘ Nothing found with	 LPDDR2 SDRAM 512M-Bit 16M x 32 1.2V/1.8V 134 -Pin
# ✘ Nothing found with	 Mobile DDR2 512Mx32 16GByte LP
# ✘ Nothing found with	 Mobile DDR2 32Mx32 1GByte LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# ✘ Nothing found with	 LPDDR2
# Extracted		 ['533Mhz']
# ✘ Nothing found with	 DDR4 256Mx16 PC2666
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 SDRAM - DDR4 Memory IC 8Gb (512M x 16) Parallel 1.6GHz
# ✘ Nothing found with	 DDR4 1Gx8 PC2666
# ✘ Nothing found with	 DDR4 1Gx8 PC2666
# ✘ Nothing found with	 DDR4 1Gx16 PC2666
# ✘ Nothing found with	 DDR4 512Mx16 PC2666
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx16 PC2400 BGA
# ✘ Nothing found with	 DDR4 512Mx8 PC2400 FBGA Ind. Grade
# ✘ Nothing found with	 DDR4 512Mx16 PC2133 TFBGA
# ✘ Nothing found with	 DDR4 4Gx4 PC2400 1.2V
# ✘ Nothing found with	 DDR4 2Gx8 PC2400 1.2V
# ✘ Nothing found with	 DDR4 2Gx8 PC2400
# ✘ Nothing found with	 DDR4 2Gx8 PC2400
# ✘ Nothing found with	 DDR4 2Gx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx16 PC2400
# ✘ Nothing found with	 DDR4 2Gx4 PC2400
# ✘ Nothing found with	 DDR4 2Gx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx16 PC2133
# ✘ Nothing found with	 DDR4 2Gx8 PC2133
# ✘ Nothing found with	 DDR4 2Gx4 PC2666
# ✘ Nothing found with	 DDR4 2Gx4 PC2133
# ✘ Nothing found with	 DDR4 2Gx4 PC2133
# ✘ Nothing found with	 DDR4 2Gx4 PC2133
# ✘ Nothing found with	 DDR4 2Gx4 PC2133
# ✘ Nothing found with	 DDR4 1Gx4 PC2666
# ✘ Nothing found with	 DDR4 1Gx16 PC2400
# ✘ Nothing found with	 DDR4 1Gx16 PC2400
# ✘ Nothing found with	 DDR4 1Gx16 PC1866
# ✘ Nothing found with	 DDR4 1Gx8 PC2666
# ✘ Nothing found with	 DDR4 1Gx8 PC2666
# ✘ Nothing found with	 DDR4 1Gx8 PC2666
# ✘ Nothing found with	 DDR4 1Gx8 PC2666
# ✘ Nothing found with	 DDR4 1Gx8 PC2666
# ✘ Nothing found with	 DDR4 512Mx16 PC2666
# ✘ Nothing found with	 DDR4 1Gx8 PC2666
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx8 PC2400 ind temp
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx4 PC2400
# ✘ Nothing found with	 DDR4 1Gx4 PC2400
# ✘ Nothing found with	 DDR4 512Mx16 PC2666
# ✘ Nothing found with	 DDR4 512Mx16 PC2666
# ✘ Nothing found with	 DDR4 1Gx4 PC2400
# ✘ Nothing found with	 DDR4 1Gx4 PC2400
# ✘ Nothing found with	 DDR4 1Gx4 PC2400
# ✘ Nothing found with	 DDR4 1Gx4 PC2400
# ✘ Nothing found with	 DDR4 1Gx4 PC2133
# ✘ Nothing found with	 DDR4 1Gx4 PC2133
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 256Mx16 PC3200
# ✘ Nothing found with	 DDR4 256Mx16 PC2666
# ✘ Nothing found with	 DDR4 256Mx16 PC2666
# ✘ Nothing found with	 DDR4 256Mx16 PC2666
# ✘ Nothing found with	 DDR4 256Mx16 PC2666
# ✘ Nothing found with	 DDR4 256Mx16 PC2666
# ✘ Nothing found with	 DDR4 256Mx16 PC2666
# ✘ Nothing found with	 DDR4 256Mx16 PC2400
# ✘ Nothing found with	 DDR4 256Mx16 PC2400
# ✘ Nothing found with	 DDR4 256Mx16 PC2400 FBGA
# ✘ Nothing found with	 DDR4 256Mx16 PC2400
# ✘ Nothing found with	 DDR4 256Mx16 PC2400
# ✘ Nothing found with	 DDR4 256Mx16 PC2400 Ind. Temp
# ✘ Nothing found with	 DDR4 256Mx16 PC2400
# ✘ Nothing found with	 DDR4 256Mx16 PC2400
# ✘ Nothing found with	 DDR4 256Mx16 PC2400
# ✘ Nothing found with	 DDR4 256Mx16 PC2133
# ✘ Nothing found with	 DDR4 256Mx16 PC2133
# ✘ Nothing found with	 DDR4 256Mx16 PC2133
# ✘ Nothing found with	 DDR4 256Mx16 PC2133
# ✘ Nothing found with	 DDR4 256Mx16 PC2133
# ✘ Nothing found with	 DDR4 512Mx16 PC2666 TFBGA
# ✘ Nothing found with	 DDR4 512Mx16 PC2666
# ✘ Nothing found with	 DDR4 512Mx16 PC2400
# ✘ Nothing found with	 DDR4 512Mx16 PC2400
# ✘ Nothing found with	 DDR4 512Mx16 PC2400
# ✘ Nothing found with	 DDR4 512Mx16 PC2400
# ✘ Nothing found with	 DDR4 512Mx16 PC2400 TFBGA
# ✘ Nothing found with	 DDR4 512Mx16 PC2400
# ✘ Nothing found with	 DDR4 512Mx16 PC2400
# ✘ Nothing found with	 DDR4 512Mx16 PC2400 FBGA
# ✘ Nothing found with	 DDR4 512Mx16 PC2133
# ✘ Nothing found with	 DDR4 512Mx16 PC2133
# ✘ Nothing found with	 DDR4 512Mx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx8 PC2400 Industrial
# ✘ Nothing found with	 DDR4 512Mx8 PC2400 FBGA
# ✘ Nothing found with	 DDR4 512Mx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2400 FBGA
# ✘ Nothing found with	 DDR4 512Mx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2666 FBGA
# ✘ Nothing found with	 DDR4 512Mx8 PC2666
# ✘ Nothing found with	 DDR4 512Mx8 PC2666
# ✘ Nothing found with	 DDR4 512Mx8 PC2666
# ✘ Nothing found with	 DDR4 4Gx4 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2666
# ✘ Nothing found with	 DDR4 512Mx16 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2133 FBGA
# ✘ Nothing found with	 DDR4 512Mx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx8 PC2400 Industrial
# ✘ Nothing found with	 DDR4 512Mx8 PC2133
# ✘ Nothing found with	 DDR4 512Mx8 PC2133
# ✘ Nothing found with	 DDR4 512Mx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx16 PC2666
# ✘ Nothing found with	 DDR4 512Mx8 PC2133
# ✘ Nothing found with	 DDR4 1Gx8 PC2666
# ✘ Nothing found with	 DDR4 512Mx16 PC2666
# ✘ Nothing found with	 DDR4 512Mx8 PC2133
# ✘ Nothing found with	 DDR4 512Mx16 PC2666
# ✘ Nothing found with	 DDR4 1Gx4 PC2666
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx16 PC2400
# ✘ Nothing found with	 DDR4 512Mx16 PC2400 Industrial
# ✘ Nothing found with	 DDR4 512Mx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx8 PC2400
# ✘ Nothing found with	 DDR4 512Mx8 PC2400
# ✘ Nothing found with	 DDR4 1Gx16 PC2666
# ✘ Nothing found with	 DDR4 256Mx16 PC2666
# ✘ Nothing found with	 DDR4 256Mx16 PC2400 Industrial
# ✘ Nothing found with	 DDR4 8Gx72 PC2133 LRDIMM
# ✘ Nothing found with	 DDR4 512Mx8 PC2666 FBGA
# ✘ Nothing found with	 DDR4 512Mx8 PC2666 FBGA
# ✘ Nothing found with	 DDR4 2Gx4 PC2666
# ✘ Nothing found with	 DDR4 4Gx4 PC2666
# ✘ Nothing found with	 DDR3 128Mx8 PC1333
# ✘ Nothing found with	 test
# ✘ Nothing found with	 DDR3 128Mx16 PC1600
# ✘ Nothing found with	 DDR3 128Mx16 PC1600 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3L 1Gx8 PC1866
# ✘ Nothing found with	 DDR3 256Mx8 PC1600 1.5v
# ✘ Nothing found with	 DDR3 128Mx8 PC1600
# ✘ Nothing found with	 SDRAM - DDR3 128Mx16 PC2400
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 Low Voltage
# ✘ Nothing found with	 DDR3 512Mx8 PC2133 Ind Temp
# ✘ Nothing found with	 DDR3 256Mx16 PC1866
# ✘ Nothing found with	 DDR3 64Mx16 PC1600
# ✘ Nothing found with	 DDR3 128Mx16 PC1600
# ✘ Nothing found with	 DDR3 128Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 256Mx16 PC2133 Ind. Temp.
# ✘ Nothing found with	 DDR3 256Mx16 PC1866 1.5V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 Ind. Grade
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 Ind. Grade
# ✘ Nothing found with	 DDR3 64Mx16 PC1600
# ✘ Nothing found with	 SDRAM - DDR3 128Mx16 PC2400
# ✘ Nothing found with	 DDR3 512Mx16 PC1866
# ✘ Nothing found with	 DDR3 512Mx16 PC1866
# ✘ Nothing found with	 DDR3 512Mx16 PC1866
# ✘ Nothing found with	 DDR3 512Mx16 PC1866
# ✘ Nothing found with	 DDR3 512Mx16 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC2133
# ✘ Nothing found with	 DDR3 512Mx8 PC2133
# ✘ Nothing found with	 DDR3 512Mx8 PC2133 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC2133 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC2133 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC2133
# ✘ Nothing found with	 DDR3 512Mx8 PC2133
# ✘ Nothing found with	 DDR3 512Mx8 PC2133 1.5V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.5V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.5V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.5V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC2133
# ✘ Nothing found with	 DDR3 512mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx8 PC1866
# ✘ Nothing found with	 DDR3 512Mx4 PC1866
# ✘ Nothing found with	 DDR3 512Mx4 PC1866
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx16 PC1600 FBGA CL11
# ✘ Nothing found with	 DDR3 512Mx16 PC1600 FBGA CL11
# ✘ Nothing found with	 DDR3 512Mx16 PC1600 FBGA CL11
# ✘ Nothing found with	 DDR3 128Mx16 PC1600 1.35V Industrial
# ✘ Nothing found with	 DDR3 512Mx16 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512MX8 PC1600 1.5V
# ✘ Nothing found with	 DDR3 512MX8 PC1600 1.5V ETT
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512mx8 PC1600
# ✘ Nothing found with	 DDR3 512mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 Ind. Temp.
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 1.35V Ind Temp
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 1.5V
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1866 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 deul die
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 Low Voltage
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 1.35V FBGA Ind
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512X8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 Ind Temp
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600 Ind Temp
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx8 PC1600
# ✘ Nothing found with	 DDR3 512Mx4 PC1600 FBGA
# ✘ Nothing found with	 DDR3 512Mx4 PC1600 FBGA
# ✘ Nothing found with	 DDR3 512Mx4 PC1600
# ✘ Nothing found with	 DDR3 512Mx4 PC1600
# ✘ Nothing found with	 DDR3 512Mx4 PC1600
# ✘ Nothing found with	 DDR3 512Mx4 PC1600
# ✘ Nothing found with	 DDR3 512Mx4 PC1600
# ✘ Nothing found with	 DDR3 512MX4 PC1600
# ✘ Nothing found with	 DDR3 512Mx4 PC1600
# ✘ Nothing found with	 DDR3 512Mx4 PC1600
# ✘ Nothing found with	 DDR3 512Mx4 PC1600
# ✘ Nothing found with	 DDR3 512MX4 PC1600
# ✘ Nothing found with	 DDR3 512Mx4 PC1600 1.35V
# ✘ Nothing found with	 DDR3 512Mx16 PC1333
# ✘ Nothing found with	 DDR3 512Mx16 PC1333
# ✘ Nothing found with	 DDR3 512Mx16 PC1333
# ✘ Nothing found with	 DDR3 512Mx16 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512MX8 PC1333 1.5V
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC 1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333 ( crossline )
# ✘ Nothing found with	 DDR3 512x8 PC 1333
# ✘ Nothing found with	 DDR3 512x8 PC 1333
# ✘ Nothing found with	 DDR3 512x8 PC 1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333 FBGA 1.35v
# ✘ Nothing found with	 DDR3 512Mx4 PC1333 FBGA 1.35v
# ✘ Nothing found with	 DDR3 512Mx4 PC1333 FBGA 1.35v
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333 FBGA 1.35v
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333 FBGA 1.35v
# ✘ Nothing found with	 DDR3 512Mx4 PC1333 1.35V
# ✘ Nothing found with	 DDR3 512Mx4 PC1333 FBGA 1.35v
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333, 1.35v
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512Mx4 PC1333
# ✘ Nothing found with	 DDR3 512MX4 PC1333
# ✘ Nothing found with	 DDR3 512Mx8 PC1333 1.35V
# ✘ Nothing found with	 DDR3 512Mx8 PC1066
# ✘ Nothing found with	 DDR3 512Mx8 PC1066
# ...
# ✘ Nothing found with	 FPM 1Mx16-60 5V 4K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 3.3 4K TSOP
# ✘ Nothing found with	 FPM 1Mx16-6S 3.3V 4K TSOP
# ✘ Nothing found with	 FPM 1MX16-6 4K 3.3 TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 4K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 4K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 4K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 4K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 4K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 4K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 3.3 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ Ind. Temp
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K TSOP2 Ind. Temp.
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 1K TSOP Ind. Temp
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K TSOP2
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 1K TSOP2
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 1K 5V SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ Ind Temp
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 1K
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 EDO 1Mx16-60 3.3 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 3.3 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 3.3 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 3.3v 1K TSOP Low power
# ✘ Nothing found with	 FPM 1Mx16-60 3.3 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 5V 1K
# ✘ Nothing found with	 FPM 1Mx16-60 5v
# ✘ Nothing found with	 FPM 1Mx16-60
# ✘ Nothing found with	 FPM 1Mx16-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 5V TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V SOJ
# ✘ Nothing found with	 FPM 1Mx16-60
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V TSOP
# ✘ Nothing found with	 FPM 1Mx16-60
# ✘ Nothing found with	 FPM 1Mx16-60 SOJ
# ✘ Nothing found with	 FPM 1Mx16-60
# ✘ Nothing found with	 FPM 1Mx16-60
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V SOJ
# ✘ Nothing found with	 FPM 1Mx16-60
# ✘ Nothing found with	 FPM 1Mx16-60 TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V SOJ
# ✘ Nothing found with	 FPM 1Mx16-60 3.3 TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 3.3V SOJ
# ✘ Nothing found with	 FPM 1Mx16-60
# ✘ Nothing found with	 FPM 1Mx16-60 3.3 TSOP
# ✘ Nothing found with	 FPM 1Mx16-60 SOJ
# ✘ Nothing found with	 FPM 1Mx16-50 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-50 3.3V 1K TSOP Ind. Temp
# ✘ Nothing found with	 FPM 1Mx16-50 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-50 5V 1K TSOP2
# ✘ Nothing found with	 FPM 1Mx16-50 3.3V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-50 3.3V 1K TSOP2
# ✘ Nothing found with	 FPM 1Mx16-50 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-50 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-50 3.3V 1K SOJ
# ✘ Nothing found with	 FPM SOJ 1Mx16-50
# ✘ Nothing found with	 FPM 1Mx16-50 3.3 TSOP
# ✘ Nothing found with	 FPM 1Mx16-50 3.3V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-50 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-50 3.3 1K TSOP
# ✘ Nothing found with	 FPM 1Mx16-50 3.3V TSOP
# ✘ Nothing found with	 FPM 1Mx16-50 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx16-50
# ✘ Nothing found with	 FPM 1Mx16-50 3.3 TSOP
# ✘ Nothing found with	 FPM 1Mx16 SOJ 5V
# ✘ Nothing found with	 FPM 1Mx16 TSOP 5V
# ✘ Nothing found with	 FPM 1Mx16 5V SOJ
# ✘ Nothing found with	 FPM 1Mx16 3.3V 1K SR TSOP
# ✘ Nothing found with	 FPM 1Mx16 3.3V
# ✘ Nothing found with	 FPM 1Mx16 3.3V
# ✘ Nothing found with	 FPM 1Mx16 3.3volts TSOP
# ✘ Nothing found with	 FPM 1Mx16 5V 4K SOJ
# ✘ Nothing found with	 FPM 1Mx16 5V 1K TSOP
# ✘ Nothing found with	 FPM 1Mx4-80 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-80 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-8 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-80 5V TSOP
# ✘ Nothing found with	 FPM 1Mx4-70 5V TSOP
# ✘ Nothing found with	 FPM 1Mx4-70 5V TSOP
# ✘ Nothing found with	 FPM 1Mx4-70 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-7 SOJ
# ✘ Nothing found with	 FPM 1Mx4-7
# ✘ Nothing found with	 FPM 1Mx4-70 3.3V SOJ
# ✘ Nothing found with	 FPM 1Mx4-70 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-7 ZIP
# ✘ Nothing found with	 FPM 1Mx4-70 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx4-70 5V SOJ T
# ✘ Nothing found with	 FPM 1Mx4-70 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx4-70 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-70 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-70 5V ZIP
# ✘ Nothing found with	 FPM 1Mx4-70 3.3V TSOP
# ✘ Nothing found with	 FPM 1Mx4-70 3.3V SOJ
# ✘ Nothing found with	 FPM 1Mx4-70 3.3V SOJ
# ✘ Nothing found with	 FPM 1Mx4-70 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-70 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 5V 2K SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 5V 2K SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 3.3V TSOP
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-6 ZIP
# ✘ Nothing found with	 FPM 1Mx4-60
# ✘ Nothing found with	 FPM 1Mx4-60 ZIP
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ LP
# ✘ Nothing found with	 FPM 1Mx4-60 SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx4-60
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 TSOP
# ✘ Nothing found with	 FPM 1Mx4-6 5V SOJ Quad CAS
# ✘ Nothing found with	 FPM 1Mx4-60 TSOP
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 TSOP
# ✘ Nothing found with	 FPM 1Mx4-60 5V TSOP
# ✘ Nothing found with	 FPM 1Mx4-60 SOJ Low power
# ✘ Nothing found with	 FPM 1Mx4-60 5V ZIP
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 5V TSOP
# ✘ Nothing found with	 FPM 1Mx4-60 5V TSOP
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 5V ZIP
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-60ns SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 TSOP
# ✘ Nothing found with	 FPM 1Mx4-6 5V SOJ Quad CAS
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-6 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 5V TSOP
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-6 SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4-50 SOJ
# ✘ Nothing found with	 FPM 1Mx4 ZIP
# ✘ Nothing found with	 FPM 1Mx4 ZIP
# ✘ Nothing found with	 FPM 1Mx4 PB Free
# ✘ Nothing found with	 FPM 1Mx4
# ✘ Nothing found with	 FPM 1Mx4 5V SOJ
# ✘ Nothing found with	 FPM 1Mx4 TSOP
# ✘ Nothing found with	 FPM 1Mx4 TSOP
# ✘ Nothing found with	 FPM 1Mx2-70 5V SOJ
# ✘ Nothing found with	 FPM 1Mx2-60 5V SOJ
# ✘ Nothing found with	 FPM 1MX1-80 SOJ
# ✘ Nothing found with	 FPM 1Mx1-80
# ✘ Nothing found with	 FPM 1Mx1-70 5V DIP
# ✘ Nothing found with	 FPM 1Mx1-70 SOJ
# ✘ Nothing found with	 FPM 1Mx1-70 5V SOJ
# ✘ Nothing found with	 FPM 1Mx1-70 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx1-70 5V
# ✘ Nothing found with	 FPM 1Mx1-70 5V SOJ
# ✘ Nothing found with	 FPM 1Mx1-70 5V 1K SOJ
# ✘ Nothing found with	 FPM 1Mx1-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx1-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx1-60 5V SOJ
# ✘ Nothing found with	 FPM 1Mx1-10 Zip
# ✘ Nothing found with	 FPM 1Mx1
# ✘ Nothing found with	 FPM 1Mx1 5V SOJ
# ✘ Nothing found with	 FPM 512Kx9-60 SOJ 1K
# ✘ Nothing found with	 FPM 512Kx9-60 5V SOJ
# ✘ Nothing found with	 FPM 512Kx8-8 5V SOJ
# ✘ Nothing found with	 FPM 512Kx8-8
# ✘ Nothing found with	 FPM 512Kx8-80 ZIP
# ✘ Nothing found with	 FPM 512Kx8-80 5V 1K SOJ
# ✘ Nothing found with	 FPM 512Kx8-70 5V SOJ
# ✘ Nothing found with	 FPM 512Kx8-7 5V SOJ
# ✘ Nothing found with	 FPM 512Kx8-7 5V SOJ
# ✘ Nothing found with	 FPM 512Kx8-70 5V 1K SOJ
# ✘ Nothing found with	 FPM 512Kx8-70 ZIP
# ✘ Nothing found with	 FPM 512Kx8-70 5V SOJ SR reel
# ✘ Nothing found with	 FPM 512Kx8-70 5V 1K SOJ
# ✘ Nothing found with	 FPM 512Kx8-70
# ✘ Nothing found with	 FPM 512Kx8-70 5V 1K SOJ
# ✘ Nothing found with	 FPM 512Kx8-70 SOJ Self
# ✘ Nothing found with	 FPM 512Kx8-70 SOJ 1K
# ✘ Nothing found with	 FPM 512Kx8-70 SOJ 1K
# ✘ Nothing found with	 FPM 512Kx8-70 SOJ
# ✘ Nothing found with	 FPM 512KX8-60 5V SOJ
# ✘ Nothing found with	 FPM 512Kx8-6
# ✘ Nothing found with	 FPM 512Kx8-6 5V SOJ
# ✘ Nothing found with	 FPM 512Kx8-60 1K SOJ
# ✘ Nothing found with	 FPM 512Kx8-60 SOJ 1K
# ✘ Nothing found with	 FPM 512Kx8-6 5V 1K SOJ
# ✘ Nothing found with	 FPM 512Kx8 3.3
# ✘ Nothing found with	 FPM 256Kx18-7 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-8
# ✘ Nothing found with	 FPM 256Kx16-8 5V SOJ low power
# ✘ Nothing found with	 FPM 256Kx16-70
# ✘ Nothing found with	 FPM 256Kx16-70
# ✘ Nothing found with	 FPM 256Kx16-7 5V ZIP
# ✘ Nothing found with	 FPM 256Kx16-7 5V 1CAS SOJ
# ✘ Nothing found with	 FPM 256Kx16-7 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-7 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-7
# ✘ Nothing found with	 FPM 256Kx16-7 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-7 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-70 SOJ
# ✘ Nothing found with	 FPM 256Kx16-70 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-70 SOJ
# ✘ Nothing found with	 FPM 256Kx16-70 5V TSOP SR
# ✘ Nothing found with	 FPM 256Kx16-70 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-70 5V SOJ
# ✘ Nothing found with	 FPM 256Kx16-70 SOJ
# ✘ Nothing found with	 FPM 256Kx16-70 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-7 5v SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 5V 1K TSOP
# ✘ Nothing found with	 FPM 256Kx16-60 5V 1K
# ✘ Nothing found with	 FPM 256Kx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-60
# ✘ Nothing found with	 FPM 256Kx16-6 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-6 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-6 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-6 5V 1K SOJ
# ✘ Nothing found with	 FPM 256kx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 1K refresh 2WE
# ✘ Nothing found with	 FPM 256Kx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 5V SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 5V SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 3.3V TSOP2
# ✘ Nothing found with	 FPM 256Kx16-60 SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 1K 5V
# ✘ Nothing found with	 FPM 256Kx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 5V TSOP SR
# ✘ Nothing found with	 FPM 256Kx16-60 5V TSOP
# ✘ Nothing found with	 FPM 256Kx16-60 3.3V TSOP
# ✘ Nothing found with	 FPM 256Kx16-60 5V SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 5V TSOP
# ✘ Nothing found with	 FPM 256Kx16-60 5V TSOP
# ✘ Nothing found with	 FPM 256Kx16-60 5V SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 5V TSOP
# ✘ Nothing found with	 FPM 256Kx16-60 5V SOJ
# ✘ Nothing found with	 FPM 256Kx16-6 TSOP
# ✘ Nothing found with	 FPM 256Kx16-60 5V SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 TSOP
# ✘ Nothing found with	 FPM 256Kx16-60 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 5V SOJ
# ✘ Nothing found with	 2MX8-60 TSOP FPM
# ✘ Nothing found with	 FPM 256Kx16-60 TSOP
# ✘ Nothing found with	 FPM 256Kx16-60
# ✘ Nothing found with	 FPM 256Kx16-60 TSOP
# ✘ Nothing found with	 FPM 256Kx16-6 5v SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 SOJ
# ✘ Nothing found with	 FPM 256Kx16-60 SOJ
# ✘ Nothing found with	 FPM 256Kx16-50 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-50 5V 1K SOJ
# ✘ Nothing found with	 FPM TSOP 256Kx16-50
# ✘ Nothing found with	 FPM 256Kx16-50 3.3V TSOP
# ✘ Nothing found with	 FPM 256Kx16-50 TSOP
# ✘ Nothing found with	 FPM 256Kx16-50 5V TSOP
# ✘ Nothing found with	 FPM 256Kx16-45 5V 1K TSOP
# ✘ Nothing found with	 FPM 256Kx16-35 5V 1K SOJ
# ✘ Nothing found with	 FPM 256Kx16-35 5V SOJ
# ✘ Nothing found with	 FPM 256Kx16-35 5V TSOP
# ✘ Nothing found with	 FPM 256Kx16-35 3.3V SOJ
# ✘ Nothing found with	 FPM 256Kx16-28 5V SOJ
# ✘ Nothing found with	 FPM 256Kx16-10
# ✘ Nothing found with	 FPM 256kx16 TSOP
# ✘ Nothing found with	 FPM 256Kx8-60 5V SOJ
# ✘ Nothing found with	 FPM 256Kx8-60 5V TSOP
# ✘ Nothing found with	 FPM 256Kx8
# ✘ Nothing found with	 FPM 256Kx8
# ✘ Nothing found with	 FPM 256Kx4-80 5V SOJ
# ✘ Nothing found with	 FPM 256Kx4-80
# ✘ Nothing found with	 FPM 256Kx4-70 ZIP
# ✘ Nothing found with	 FPM 256Kx4-70 5V
# ✘ Nothing found with	 FPM 256Kx4-70 5V DIP
# ✘ Nothing found with	 FPM 256Kx4-7 5V SOJ
# ✘ Nothing found with	 FPM 256Kx4-70 5V SOJ
# ✘ Nothing found with	 FPM 256Kx4-70 5V ZIP
# ✘ Nothing found with	 FPM 256Kx4-70 ZIP
# ✘ Nothing found with	 FPM 256Kx4-70 ZIP
# ✘ Nothing found with	 FPM 256Kx4-70 5V DIP
# ✘ Nothing found with	 FPM 256Kx4-70 5V
# ✘ Nothing found with	 FPM 256Kx4-6 5V SOJ
# ✘ Nothing found with	 FPM 256Kx4-6 5V DIP
# ✘ Nothing found with	 FPM 256Kx4-6 5V SOJ
# ✘ Nothing found with	 FPM 256Kx4-6 5V SOJ
# ✘ Nothing found with	 FPM 256Kx4-6 5V ZIP
# ✘ Nothing found with	 FPM 256Kx4-60 5V SOJ
# ✘ Nothing found with	 FPM 256Kx4-60 SOJ
# ✘ Nothing found with	 FPM 256Kx4-60 5V SOJ
# ✘ Nothing found with	 FPM 256Kx4-60 ZIP
# ✘ Nothing found with	 FPM 256Kx4-60 ZIP
# ✘ Nothing found with	 FPM 256Kx4-60
# ✘ Nothing found with	 FPM 256Kx4-45 SOJ
# ✘ Nothing found with	 FPM 256Kx4-10 ZIP
# ✘ Nothing found with	 FPM 256Kx4 ZIP
# ✘ Nothing found with	 FPM 256Kx4 ZIP
# ✘ Nothing found with	 FPM 256kx4
# ✘ Nothing found with	 FPM 256Kx4
# ✘ Nothing found with	 FPM 256Kx4
# ✘ Nothing found with	 FPM 256kx1
# ✘ Nothing found with	 FPM 128Kx16-5
# ✘ Nothing found with	 FPM SOJ 128KX8-45
# ✘ Nothing found with	 FPM SOJ 128Kx8-45
# ✘ Nothing found with	 FPM SOJ 128Kx8-40
# ✘ Nothing found with	 FPM SOJ 128Kx8-50
# ✘ Nothing found with	 FPM 64Kx16-80 5V SOJ
# ✘ Nothing found with	 FPM 64Kx16-70 5V SOJ
# ✘ Nothing found with	 FPM 64Kx16-70 5v SOJ
# ✘ Nothing found with	 FPM 64Kx16 SOJ
# ✘ Nothing found with	 FPM 64Kx16 5V SOJ
# ✘ Nothing found with	 FPM 64Kx4
# ✘ Nothing found with	 FPM 256Mx16 SOJ
# ✘ Nothing found with	 Rambus DRAM PC 800 mono (Pb-free)
# ✘ Nothing found with	 Rambus DRAM PC 800 mono
# ✘ Nothing found with	 Rambus DRAM PC 600 mono (Pb-free)
# ✘ Nothing found with	 288Mbit RDRAM 512K x 18 bit
# ✘ Nothing found with	 288Mbit RDRAM 512K x 18 bit
# ✘ Nothing found with	 288Mbit RDRAM 512K x 18 bit
# ✘ Nothing found with	 288Mbit RDRAM 512K x 18 bit
# ✘ Nothing found with	 Direct RDRAM 288Mx18
# ✘ Nothing found with	 Rambus DRAM 128Mbit
# ✘ Nothing found with	 Rambus 2Mx8 16M
# ✘ Nothing found with	 Rambus 2Mx8 16M
# ✘ Nothing found with	 Rambus

# %% [markdown]
# # Advanced options
# For even more complex patterns you would need to check the content around what is being matched.
#
# <table class="table table-striped table-bordered table-hover table-condensed">
#
# <colgroup>
# <col  class="left">
#
# <col  class="left">
# </colgroup>
# <thead>
# <tr>
# <th scope="col" class="text-left"></th>
# <th scope="col" class="text-left"><b>Description</b></th>
# <th scope="col" class="text-left"><b>Use case</b></th>
# </tr>
# </thead>
# <tbody>
#
#
# <tr>
# <td class="text-left"><code>"(?P&lt;name&gt;&#x2026;)"</code></td>
# <td class="text-left">The substring matched by the group is accessible by name.</td>
# <td class="text-left"></td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"(?P=name)"</code></td>
# <td class="text-left">Matches the text matched earlier by the group named name.</td>
# <td class="text-left"></td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"(?=&#x2026;)"</code></td>
# <td class="text-left">Matches if &#x2026; matches next, but doesn't consume the string.</td>
# <td class="text-left">Use instead of creating [GROUPS](#groups), and selecting which ones to keep</td>
# </tr>
#
# <tr>
# <td class="text-left"><code>"(?&lt;=&#x2026;)"</code></td>
# <td class="text-left">Matches if preceded by &#x2026; (must be fixed length).</td>
# <td class="text-left">Use instead of creating [GROUPS](#groups), and selecting which ones to keep</td>
# </tr>
#
#
#
# <tr>
# <td class="text-left"><code>"(?&lt;!&#x2026;)"</code></td>
# <td class="text-left">Matches if not preceded by &#x2026; (must be fixed length).</td>
# <td class="text-left">Use to check for things to not match</td>
# </tr>
#
# </tbody>
# </table>

# %% [markdown]
# # Trimming white spaces
# Cleaning using regular experssions will often result in trailing white spaces at start and ends of expressions, which need to be eliminated using the following script:
# 1. Match an experssion with 3 groups: 1 - leading white space; 2 - main content; 3 trailing white space
# 2. Return only the main content

# %%
def trim_white_space(string):
    """
    __ Parameters __
    string to trim white space from

    __ Description __
    trip from start and end of string

    __ Return __
    trimmed string
    """

    # 1 - search for spaces
    groupMatch = re.match("^(\s*)(.*)(\s*)$", string)
    if(groupMatch):
        return groupMatch.group(2)
    else:
        return string

# %% [markdown]
# # Extra datasets to practise filtering on

# %%
data = read_pickle("datasets/Module_OfferScraperOutput.pkl")
brand = data['Brand']
qty = data['Qty']
price = data['Price']
description = data['Description']

# %%
data = read_pickle("datasets/SSD_OfferScraperOutput.pkl")
brand = data['Brand']
qty = data['Qty']
price = data['Price']
description = data['Description']

# %%
data = read_pickle("datasets/FlashCard_OfferScraperOutput.pkl")
brand = data['Brand']
qty = data['Qty']
price = data['Price']
description = data['Description']
